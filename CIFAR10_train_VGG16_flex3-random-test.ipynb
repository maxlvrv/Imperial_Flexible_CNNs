# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# ================================================= Flexible Layer ================================================================================

    
class FlexiLayer(nn.Module): # class FlexiLayer(nn.Conv2d):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 padding=0):
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        super(FlexiLayer, self).__init__()
        
        self.t_1 = nn.Conv2d(self.in_channels, self.out_channels, self.kernel_size, self.stride, self.padding)
        self.t_2 = nn.MaxPool2d(self.kernel_size, self.stride, self.padding) # get max result with the same kernel size
        self.m = nn.Sigmoid()
        
        #self.thresh_mean = []
        
    def forward(self, t):
        
        self.mask = torch.empty(1, self.out_channels, 30, 30).random_(2)        
        
        t_2_2 = self.mask.cuda()*self.t_2(t) # MAX if true
        t_1_1 = (1-self.mask.cuda())*self.t_1(t) # CONV if false
        t = torch.add(t_2_2, t_1_1)
        
        return t

    # ================================================= VGG-16 Network ================================================================================
class VGG16(nn.Module):
  def __init__(self):
    super(VGG16,self).__init__()

    self.block1 = nn.Sequential(
                  nn.Conv2d(in_channels = 3,out_channels = 64,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(64),
                  nn.ReLU(),
                  FlexiLayer(in_channels = 64,out_channels = 64,kernel_size = 3, padding =0),
                  nn.BatchNorm2d(64),
                  nn.ReLU(),
                  #nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.3))

    self.block2 = nn.Sequential(
                  nn.Conv2d(in_channels = 64,out_channels = 128,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(128),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 128,out_channels = 128,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(128),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.4))

    self.block3 = nn.Sequential(
                  nn.Conv2d(in_channels = 128,out_channels = 256,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(256),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(256),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(256),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.4))

    self.block4 = nn.Sequential(
                  nn.Conv2d(in_channels = 256,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2) ,
                  nn.Dropout2d(0.4))

    self.block5 = nn.Sequential(
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.5) )

    self.fc =     nn.Sequential(
                  nn.Linear(512,100),
                  nn.Dropout(0.5),
                  nn.BatchNorm1d(100),
                  nn.ReLU(),
                  nn.Dropout(0.5),
                  nn.Linear(100,10), )
                  
                  


  def forward(self,x):
    out = self.block1(x)
    out = self.block2(out)
    out = self.block3(out)
    out = self.block4(out)
    out = self.block5(out)
    out = out.view(out.size(0),-1)
    out = self.fc(out)

    return out

# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

#from models.VGG16_with_flex_v5 import *


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
# truck  bird   cat horse

# %%
# =============================================================== Model initialisation, Loss function and Optimizer =====================================
model = VGG16()
if torch.cuda.is_available():
  model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma = 0.7)

total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} trainable parameters.')
# Out:
# 14,775,646 total parameters.
# 14,775,646 trainable parameters.

# %%
# ======================== Function to get the test accuracy ===============================================================================
def test():
  correct = 0
  total = 0
  model.train(False)
  with torch.no_grad():
    for i,(images,labels)in enumerate(testloader):
      if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
      outputs = model(Variable(images))
      labels = Variable(labels)
      _,predicted = outputs.max(1)
      total += labels.size(0)
      correct += (predicted.eq(labels)).sum().item()
    print('Test accuracy: %d %%' % (
  100 * correct / total))
  return 100*(correct/total)

#======================================================= Training =========================================================================
num_epochs = 152  # Train for 150 epochs
start_epoch = 0

total_step = len(trainloader)
train_loss = []  # Store the train_loss per epoch
test_accuracy = [] # Store the test_accuracy per epoch
for epoch in range(start_epoch,num_epochs+1):
  model.train(True)
  epoch_loss  = 0
  i_count = 0
  acc_total = 0
  for i,(images,labels) in enumerate(trainloader):
    if torch.cuda.is_available():
      images = images.cuda()
      labels = labels.cuda()
    labels = Variable(labels)
    optimizer.zero_grad()
    outputs = model(Variable(images))
    loss = criterion(outputs,labels)
    epoch_loss += loss.item()
    loss.backward()
    optimizer.step()
    _,predicted = outputs.max(1)
    denom = labels.size(0)
    correct = predicted.eq(labels).sum().item()
    acc = 100*(correct/denom)
    acc_total += acc
    i_count = i_count + 1
    
    #if(i%20 == 0):  # Print the loss per 20 iterations
      #print("Epoch: ",epoch," ","Iteration: ",i," loss: ",loss.item()," Train_iter Accuracy: ",acc)
  schedule.step()
  train_loss.append(epoch_loss)
  print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
  print('\n')
  test_acc = test()      # Print the test accuracy per epoch
  test_accuracy.append(test_acc)
  
  if(epoch%150 == 0):       # Save the model every 50 epoch
    state = {
        'model': model.state_dict(),
        'acc' : test_acc,
        'optim':optimizer.state_dict(),
        'epoch' : epoch
    }
    #path = './models/VGG16-FLEX-CONV-T-nnmodule_' + 'model_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
    #torch.save(state,path)
# Out:
# Epoch:  0   Loss:  1098.9243721961975   Train Accuracy : 16.812
#
#
# Test accuracy: 15 %
# Epoch:  1   Loss:  991.6158289909363   Train Accuracy : 23.872
#
#
# Test accuracy: 24 %
# Epoch:  2   Loss:  925.7402299642563   Train Accuracy : 29.926
#
#
# Test accuracy: 32 %
# Epoch:  3   Loss:  875.3116515874863   Train Accuracy : 34.966
#
#
# Test accuracy: 40 %
# Epoch:  4   Loss:  832.7554993629456   Train Accuracy : 39.092
#
#
# Test accuracy: 47 %
# Epoch:  5   Loss:  790.6730967760086   Train Accuracy : 43.292
#
#
# Test accuracy: 51 %
# Epoch:  6   Loss:  755.6094710826874   Train Accuracy : 46.656
#
#
# Test accuracy: 53 %
# Epoch:  7   Loss:  720.0517824888229   Train Accuracy : 49.73
#
#
# Test accuracy: 56 %
# Epoch:  8   Loss:  688.8905377388   Train Accuracy : 52.792
#
#
# Test accuracy: 60 %
# Epoch:  9   Loss:  660.2131159305573   Train Accuracy : 55.336
#
#
# Test accuracy: 61 %
# Epoch:  10   Loss:  631.012081027031   Train Accuracy : 58.004
#
#
# Test accuracy: 64 %
# Epoch:  11   Loss:  609.6200448870659   Train Accuracy : 59.302
#
#
# Test accuracy: 66 %
# Epoch:  12   Loss:  586.7294247150421   Train Accuracy : 61.492
#
#
# Test accuracy: 67 %
# Epoch:  13   Loss:  566.9179827570915   Train Accuracy : 63.008
#
#
# Test accuracy: 69 %
# Epoch:  14   Loss:  548.0153651237488   Train Accuracy : 64.424
#
#
# Test accuracy: 69 %
# Epoch:  15   Loss:  533.5954903960228   Train Accuracy : 65.418
#
#
# Test accuracy: 71 %
# Epoch:  16   Loss:  514.1241954565048   Train Accuracy : 67.376
#
#
# Test accuracy: 72 %
# Epoch:  17   Loss:  500.41230976581573   Train Accuracy : 68.432
#
#
# Test accuracy: 73 %
# Epoch:  18   Loss:  485.48158699274063   Train Accuracy : 69.278
#
#
# Test accuracy: 74 %
# Epoch:  19   Loss:  473.33688920736313   Train Accuracy : 70.52
#
#
# Test accuracy: 75 %
# Epoch:  20   Loss:  447.6074737906456   Train Accuracy : 72.772
#
#
# Test accuracy: 77 %
# Epoch:  21   Loss:  433.9653911590576   Train Accuracy : 73.684
#
#
# Test accuracy: 77 %
# Epoch:  22   Loss:  423.20466339588165   Train Accuracy : 74.464
#
#
# Test accuracy: 78 %
# Epoch:  23   Loss:  414.8936772942543   Train Accuracy : 75.26
#
#
# Test accuracy: 78 %
# Epoch:  24   Loss:  401.8930035829544   Train Accuracy : 75.93
#
#
# Test accuracy: 79 %
# Epoch:  25   Loss:  395.5949056148529   Train Accuracy : 76.658
#
#
# Test accuracy: 79 %
# Epoch:  26   Loss:  390.1410727798939   Train Accuracy : 77.164
#
#
# Test accuracy: 80 %
# Epoch:  27   Loss:  380.4389188885689   Train Accuracy : 77.82
#
#
# Test accuracy: 81 %
# Epoch:  28   Loss:  371.07909202575684   Train Accuracy : 78.4
#
#
# Test accuracy: 81 %
# Epoch:  29   Loss:  362.1328015625477   Train Accuracy : 79.012
#
#
# Test accuracy: 81 %
# Epoch:  30   Loss:  355.9560854136944   Train Accuracy : 79.838
#
#
# Test accuracy: 81 %
# Epoch:  31   Loss:  351.7123103737831   Train Accuracy : 79.836
#
#
# Test accuracy: 82 %
# Epoch:  32   Loss:  342.85142382979393   Train Accuracy : 80.666
#
#
# Test accuracy: 83 %
# Epoch:  33   Loss:  339.80499136447906   Train Accuracy : 80.74
#
#
# Test accuracy: 83 %
# Epoch:  34   Loss:  328.80612790584564   Train Accuracy : 81.694
#
#
# Test accuracy: 83 %
# Epoch:  35   Loss:  323.4491649866104   Train Accuracy : 82.124
#
#
# Test accuracy: 83 %
# Epoch:  36   Loss:  324.5287544131279   Train Accuracy : 81.812
#
#
# Test accuracy: 83 %
# Epoch:  37   Loss:  316.62194204330444   Train Accuracy : 82.618
#
#
# Test accuracy: 84 %
# Epoch:  38   Loss:  310.3600107431412   Train Accuracy : 82.854
#
#
# Test accuracy: 84 %
# Epoch:  39   Loss:  302.08273151516914   Train Accuracy : 83.576
#
#
# Test accuracy: 84 %
# Epoch:  40   Loss:  283.2307275533676   Train Accuracy : 84.982
#
#
# Test accuracy: 85 %
# Epoch:  41   Loss:  276.39277413487434   Train Accuracy : 85.154
#
#
# Test accuracy: 85 %
# Epoch:  42   Loss:  269.2223274409771   Train Accuracy : 85.664
#
#
# Test accuracy: 85 %
# Epoch:  43   Loss:  263.41606241464615   Train Accuracy : 86.166
#
#
# Test accuracy: 86 %
# Epoch:  44   Loss:  259.80090394616127   Train Accuracy : 86.328
#
#
# Test accuracy: 85 %
# Epoch:  45   Loss:  258.15434896945953   Train Accuracy : 86.526
#
#
# Test accuracy: 85 %
# Epoch:  46   Loss:  254.1035976111889   Train Accuracy : 86.588
#
#
# Test accuracy: 85 %
# Epoch:  47   Loss:  250.57489222288132   Train Accuracy : 87.082
#
#
# Test accuracy: 85 %
# Epoch:  48   Loss:  245.2998979985714   Train Accuracy : 87.334
#
#
# Test accuracy: 85 %
# Epoch:  49   Loss:  244.1602803170681   Train Accuracy : 87.462
#
#
# Test accuracy: 86 %
# Epoch:  50   Loss:  239.85990405082703   Train Accuracy : 87.634
#
#
# Test accuracy: 85 %
# Epoch:  51   Loss:  236.67517840862274   Train Accuracy : 88.008
#
#
# Test accuracy: 86 %
# Epoch:  52   Loss:  232.33199614286423   Train Accuracy : 88.124
#
#
# Test accuracy: 86 %
# Epoch:  53   Loss:  232.51788076758385   Train Accuracy : 88.098
#
#
# Test accuracy: 86 %
# Epoch:  54   Loss:  228.2473293095827   Train Accuracy : 88.362
#
#
# Test accuracy: 86 %
# Epoch:  55   Loss:  224.9719696342945   Train Accuracy : 88.682
#
#
# Test accuracy: 86 %
# Epoch:  56   Loss:  221.62249985337257   Train Accuracy : 88.794
#
#
# Test accuracy: 86 %
# Epoch:  57   Loss:  218.28605511784554   Train Accuracy : 89.096
#
#
# Test accuracy: 87 %
# Epoch:  58   Loss:  218.8066329061985   Train Accuracy : 88.948
#
#
# Test accuracy: 85 %
# Epoch:  59   Loss:  219.40068632364273   Train Accuracy : 89.032
#
#
# Test accuracy: 86 %
# Epoch:  60   Loss:  196.19766353070736   Train Accuracy : 90.672
#
#
# Test accuracy: 87 %
# Epoch:  61   Loss:  187.77201791107655   Train Accuracy : 91.17
#
#
# Test accuracy: 87 %
# Epoch:  62   Loss:  182.8451512902975   Train Accuracy : 91.538
#
#
# Test accuracy: 87 %
# Epoch:  63   Loss:  182.08530634641647   Train Accuracy : 91.662
#
#
# Test accuracy: 88 %
# Epoch:  64   Loss:  179.86735020577908   Train Accuracy : 91.77
#
#
# Test accuracy: 87 %
# Epoch:  65   Loss:  172.5932745486498   Train Accuracy : 92.11
#
#
# Test accuracy: 87 %
# Epoch:  66   Loss:  170.91069301962852   Train Accuracy : 92.182
#
#
# Test accuracy: 87 %
# Epoch:  67   Loss:  170.7284859418869   Train Accuracy : 92.368
#
#
# Test accuracy: 88 %
# Epoch:  68   Loss:  169.32710106670856   Train Accuracy : 92.236
#
#
# Test accuracy: 88 %
# Epoch:  69   Loss:  172.69947890937328   Train Accuracy : 92.13
#
#
# Test accuracy: 88 %
# Epoch:  70   Loss:  167.5201844573021   Train Accuracy : 92.366
#
#
# Test accuracy: 88 %
# Epoch:  71   Loss:  164.71586836874485   Train Accuracy : 92.494
#
#
# Test accuracy: 87 %
# Epoch:  72   Loss:  163.9755186587572   Train Accuracy : 92.562
#
#
# Test accuracy: 88 %
# Epoch:  73   Loss:  162.5886792242527   Train Accuracy : 92.896
#
#
# Test accuracy: 88 %
# Epoch:  74   Loss:  163.43585346639156   Train Accuracy : 92.636
#
#
# Test accuracy: 87 %
# Epoch:  75   Loss:  159.31157346069813   Train Accuracy : 92.898
#
#
# Test accuracy: 87 %
# Epoch:  76   Loss:  157.81069685518742   Train Accuracy : 92.882
#
#
# Test accuracy: 87 %
# Epoch:  77   Loss:  153.84625931084156   Train Accuracy : 93.298
#
#
# Test accuracy: 88 %
# Epoch:  78   Loss:  155.7365030348301   Train Accuracy : 92.994
#
#
# Test accuracy: 87 %
# Epoch:  79   Loss:  155.0982313901186   Train Accuracy : 93.22
#
#
# Test accuracy: 87 %
# Epoch:  80   Loss:  138.06689935922623   Train Accuracy : 94.316
#
#
# Test accuracy: 88 %
# Epoch:  81   Loss:  131.8299454897642   Train Accuracy : 94.692
#
#
# Test accuracy: 88 %
# Epoch:  82   Loss:  128.34348098933697   Train Accuracy : 94.862
#
#
# Test accuracy: 88 %
# Epoch:  83   Loss:  127.04696947336197   Train Accuracy : 94.98
#
#
# Test accuracy: 88 %
# Epoch:  84   Loss:  123.46732592582703   Train Accuracy : 95.244
#
#
# Test accuracy: 88 %
# Epoch:  85   Loss:  121.8252315223217   Train Accuracy : 95.124
#
#
# Test accuracy: 88 %
# Epoch:  86   Loss:  123.06610205769539   Train Accuracy : 95.16
#
#
# Test accuracy: 88 %
# Epoch:  87   Loss:  118.3201943859458   Train Accuracy : 95.542
#
#
# Test accuracy: 88 %
# Epoch:  88   Loss:  119.98264437168837   Train Accuracy : 95.39
#
#
# Test accuracy: 88 %
# Epoch:  89   Loss:  119.2044178918004   Train Accuracy : 95.416
#
#
# Test accuracy: 88 %
# Epoch:  90   Loss:  115.33907037973404   Train Accuracy : 95.592
#
#
# Test accuracy: 88 %
# Epoch:  91   Loss:  116.28430803865194   Train Accuracy : 95.618
#
#
# Test accuracy: 88 %
# Epoch:  92   Loss:  117.60828521847725   Train Accuracy : 95.484
#
#
# Test accuracy: 88 %
# Epoch:  93   Loss:  112.59336147457361   Train Accuracy : 95.802
#
#
# Test accuracy: 88 %
# Epoch:  94   Loss:  114.2909968495369   Train Accuracy : 95.678
#
#
# Test accuracy: 88 %
# Epoch:  95   Loss:  112.24896617233753   Train Accuracy : 95.894
# Test accuracy: 88 %
# Epoch:  96   Loss:  113.49338552355766   Train Accuracy : 95.74
#
#
# Test accuracy: 88 %
# Epoch:  97   Loss:  110.76416938751936   Train Accuracy : 95.886
#
#
# Test accuracy: 88 %
# Epoch:  98   Loss:  111.37855233997107   Train Accuracy : 95.944
#
#
# Test accuracy: 88 %
# Epoch:  99   Loss:  112.03897178918123   Train Accuracy : 95.872
#
#
# Test accuracy: 88 %
# Epoch:  100   Loss:  102.40985333174467   Train Accuracy : 96.404
#
#
# Test accuracy: 89 %
# Epoch:  101   Loss:  95.1461185887456   Train Accuracy : 96.804
#
#
# Test accuracy: 89 %
# Epoch:  102   Loss:  91.18005600571632   Train Accuracy : 97.112
#
#
# Test accuracy: 89 %
# Epoch:  103   Loss:  90.5062838345766   Train Accuracy : 97.188
#
#
# Test accuracy: 88 %
# Epoch:  104   Loss:  92.4595043361187   Train Accuracy : 97.09
#
#
# Test accuracy: 89 %
# Epoch:  105   Loss:  90.26999515295029   Train Accuracy : 97.168
#
#
# Test accuracy: 89 %
# Epoch:  106   Loss:  87.02645529806614   Train Accuracy : 97.35
#
#
# Test accuracy: 89 %
# Epoch:  107   Loss:  87.43906249850988   Train Accuracy : 97.248
#
#
# Test accuracy: 89 %
# Epoch:  108   Loss:  86.99946773797274   Train Accuracy : 97.366
#
#
# Test accuracy: 89 %
# Epoch:  109   Loss:  85.35900373011827   Train Accuracy : 97.534
#
#
# Test accuracy: 88 %
# Epoch:  110   Loss:  84.78532517701387   Train Accuracy : 97.51
#
#
# Test accuracy: 89 %
# Epoch:  111   Loss:  84.5619074255228   Train Accuracy : 97.544
#
#
# Test accuracy: 88 %
# Epoch:  112   Loss:  82.91392363607883   Train Accuracy : 97.558
#
#
# Test accuracy: 89 %
# Epoch:  113   Loss:  82.7471187338233   Train Accuracy : 97.566
#
#
# Test accuracy: 89 %
# Epoch:  114   Loss:  83.43035996705294   Train Accuracy : 97.558
#
#
# Test accuracy: 89 %
# Epoch:  115   Loss:  82.77423691004515   Train Accuracy : 97.606
#
#
# Test accuracy: 89 %
# Epoch:  116   Loss:  83.56650096178055   Train Accuracy : 97.488
#
#
# Test accuracy: 89 %
# Epoch:  117   Loss:  82.46474852412939   Train Accuracy : 97.54
#
#
# Test accuracy: 89 %
# Epoch:  118   Loss:  83.24243401736021   Train Accuracy : 97.544
#
#
# Test accuracy: 89 %
# Epoch:  119   Loss:  82.02811218053102   Train Accuracy : 97.514
#
#
# Test accuracy: 89 %
# Epoch:  120   Loss:  78.07223588973284   Train Accuracy : 97.818
#
#
# Test accuracy: 89 %
# Epoch:  121   Loss:  75.20581305027008   Train Accuracy : 97.988
#
#
# Test accuracy: 89 %
# Epoch:  122   Loss:  73.4346483796835   Train Accuracy : 98.18
#
#
# Test accuracy: 89 %
# Epoch:  123   Loss:  72.53234958648682   Train Accuracy : 98.14
#
#
# Test accuracy: 89 %
# Epoch:  124   Loss:  71.19487575441599   Train Accuracy : 98.334
#
#
# Test accuracy: 89 %
# Epoch:  125   Loss:  70.35700083523989   Train Accuracy : 98.268
#
#
# Test accuracy: 89 %
# Epoch:  126   Loss:  68.82123247534037   Train Accuracy : 98.37
#
#
# Test accuracy: 89 %
# Epoch:  127   Loss:  70.73274068161845   Train Accuracy : 98.306
#
#
# Test accuracy: 89 %
# Epoch:  128   Loss:  68.25314382463694   Train Accuracy : 98.42
#
#
# Test accuracy: 89 %
# Epoch:  129   Loss:  68.12279290705919   Train Accuracy : 98.436
#
#
# Test accuracy: 89 %
# Epoch:  130   Loss:  67.4309378489852   Train Accuracy : 98.496
#
#
# Test accuracy: 89 %
# Epoch:  131   Loss:  67.99306675046682   Train Accuracy : 98.452
#
#
# Test accuracy: 89 %
# Epoch:  132   Loss:  67.95469614863396   Train Accuracy : 98.546
#
#
# Test accuracy: 89 %
# Epoch:  133   Loss:  66.98894489556551   Train Accuracy : 98.452
#
#
# Test accuracy: 89 %
# Epoch:  134   Loss:  66.70251066237688   Train Accuracy : 98.612
#
#
# Test accuracy: 89 %
# Epoch:  135   Loss:  66.77427649497986   Train Accuracy : 98.456
#
#
# Test accuracy: 89 %
# Epoch:  136   Loss:  65.22516153007746   Train Accuracy : 98.53
#
#
# Test accuracy: 89 %
# Epoch:  137   Loss:  66.04149777069688   Train Accuracy : 98.526
#
#
# Test accuracy: 89 %
# Epoch:  138   Loss:  67.33813846856356   Train Accuracy : 98.496
#
#
# Test accuracy: 89 %
# Epoch:  139   Loss:  66.16772698238492   Train Accuracy : 98.548
#
#
# Test accuracy: 89 %
# Epoch:  140   Loss:  64.07086478918791   Train Accuracy : 98.66
#
#
# Test accuracy: 89 %
# Epoch:  141   Loss:  62.57148901373148   Train Accuracy : 98.78
#
#
# Test accuracy: 89 %
# Epoch:  142   Loss:  62.482717361301184   Train Accuracy : 98.76
#
#
# Test accuracy: 89 %
# Epoch:  143   Loss:  61.6224348731339   Train Accuracy : 98.88
#
#
# Test accuracy: 89 %
# Epoch:  144   Loss:  61.1171989440918   Train Accuracy : 98.956
#
#
# Test accuracy: 89 %
# Epoch:  145   Loss:  60.14088676124811   Train Accuracy : 98.906
#
#
# Test accuracy: 89 %
# Epoch:  146   Loss:  60.8476297557354   Train Accuracy : 98.852
#
#
# Test accuracy: 89 %
# Epoch:  147   Loss:  60.30982483923435   Train Accuracy : 98.866
#
#
# Test accuracy: 89 %
# Epoch:  148   Loss:  59.704047955572605   Train Accuracy : 98.974
#
#
# Test accuracy: 89 %
# Epoch:  149   Loss:  60.89505959302187   Train Accuracy : 98.876
#
#
# Test accuracy: 89 %
# Epoch:  150   Loss:  58.63877423107624   Train Accuracy : 98.994
#
#
# Test accuracy: 89 %
# Epoch:  151   Loss:  58.6581427231431   Train Accuracy : 98.992
#
#
# Test accuracy: 89 %
# Epoch:  152   Loss:  58.71281746029854   Train Accuracy : 98.956
#
#
# Test accuracy: 89 %

# %%
#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 89 %
# 89.73
# Accuracy of plane : 97 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 81 %
# Accuracy of   cat : 79 %
# Accuracy of  deer : 95 %
# Accuracy of   dog : 93 %
# Accuracy of  frog : 90 %
# Accuracy of horse : 93 %
# Accuracy of  ship : 95 %
# Accuracy of truck : 100 %

# %%
'''  
The image lies between [0,1] but since I have trained the whole network on normalized input, Therefore
the min_val = -2.117 and max_val = 2.64 and not {0,1}
'''

# FGSM attack code
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, -2.117, 2.64)
    # Return the perturbed image
    return perturbed_image

def test( model, device, test_loader, epsilon ):

    # Accuracy counter
    correct = 0
    adv_examples = []

    # Loop over all examples in test set
    for data, target in test_loader:

        # Send the data and label to the device
        data, target = data.to(device), target.to(device)

        # Set requires_grad attribute of tensor. Important for Attack
        data.requires_grad = True

        # Forward pass the data through the model
        output = model(data)
        init_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability

        # If the initial prediction is wrong, dont bother attacking, just move on
        #if init_pred.item() != target.item():
        #    continue

        # Calculate the loss
        loss = F.nll_loss(output, target)

        # Zero all existing gradients
        model.zero_grad()

        # Calculate gradients of model in backward pass
        loss.backward()

        # Collect datagrad
        data_grad = data.grad.data

        # Call FGSM Attack
        perturbed_data = fgsm_attack(data, epsilon, data_grad)

        # Re-classify the perturbed image
        output = model(perturbed_data)

        # Check for success
        final_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        for i in range(0,len(final_pred)-1):
            if final_pred[i].sub(target[i]) == 0:
                correct += 1
                # Special case for saving 0 epsilon examples
                if (epsilon == 0) and (len(adv_examples) < 5):
                    adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                    adv_examples.append( (init_pred[i], final_pred[i], adv_ex) )
            else:
                # Save some adv examples for visualization later
                if len(adv_examples) < 5:
                    adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                    adv_examples.append( (init_pred[i], final_pred[i], adv_ex) )

    # Calculate final accuracy for this epsilon
    final_acc = correct/float(len(test_loader))
    print("Epsilon: {}\tTest Accuracy = {} / {} = {}".format(epsilon, correct, len(test_loader), final_acc))

    # Return the accuracy and an adversarial example
    return final_acc, adv_examples

# %%
#evaluate model
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = model(images.cuda())
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.cuda()).sum().item()

print('Accuracy on the test dataset is: %f %%' % (
    100 * correct / total))
# Out:
# Accuracy on the test dataset is: 89.730000 %

# %%
accuracies = []
examples = []
epsilons = [0, .05, .1, .15, .2, .25, .3]

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
use_cuda=True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

# Run test for each epsilon
for eps in epsilons:
    acc, ex = test(model, device, testloader, eps)
    accuracies.append(acc)
    examples.append(ex)
# Out:
# CUDA Available:  True
# Epsilon: 0	Test Accuracy = 8883 / 100 = 88.83
# Epsilon: 0.05	Test Accuracy = 5764 / 100 = 57.64
# Epsilon: 0.1	Test Accuracy = 4971 / 100 = 49.71
# Epsilon: 0.15	Test Accuracy = 4694 / 100 = 46.94
# Epsilon: 0.2	Test Accuracy = 4473 / 100 = 44.73
# Epsilon: 0.25	Test Accuracy = 4350 / 100 = 43.5
# Epsilon: 0.3	Test Accuracy = 4144 / 100 = 41.44

# %%
plt.figure(figsize=(5,5))
plt.plot(epsilons, torch.tensor(accuracies).div(100), "*-")
plt.yticks(np.arange(0, 1.1, step=0.1))
plt.xticks(np.arange(0, .35, step=0.05))
plt.title("Accuracy vs Epsilon")
plt.xlabel("Epsilon")
plt.ylabel("Accuracy")
plt.show()

# %%
accuracies2 = [88.67, 55.52, 45.44, 39.35, 35.13, 31.4, 27.98]

accuraciesflex = [89.17, 56.6, 50.11, 47.79, 46.13, 44.38, 42.54]

accuracies2base = [0.9055, 0.4994, 0.4425, 0.4167, 0.394, 0.3656, 0.328]

plt.figure(figsize=(5,5))
plt.plot(epsilons, accuracies2base, "*-", label = "2) BaseVGG16")
#plt.plot(epsilons, torch.tensor(accuracies2).div(100), "*-", label = "BaseVGG16")
plt.plot(epsilons, torch.tensor(accuracies).div(100), "*-", label = "FlexiVGG16(random)")
plt.plot(epsilons, torch.tensor(accuraciesflex).div(100), "*-", label = "FlexiVGG16")
plt.yticks(np.arange(0, 1.1, step=0.1))
plt.xticks(np.arange(0, .35, step=0.05))
plt.title("Accuracy vs Epsilon")
plt.xlabel("Epsilon")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
