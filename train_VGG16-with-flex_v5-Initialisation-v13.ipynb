# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

from models.VGG16_with_flex_v8 import *


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
#  frog  ship  frog   car

# %%
# =============================================================== Model initialisation, Loss function and Optimizer =====================================
model = VGG16()
# Load the pretrained model
#state = torch.load('./models/VGG16-flex-v5-block1-model_150_90.pth')
#model.load_state_dict(state['model'])
state_dict = model.state_dict()
thr = state_dict["block1.3.threshold1"]
state_dict["block1.3.threshold1"] = Variable(thr.data.new(1, 64, 30, 30).uniform_(0,0)) # make a random tensor of same type and device as original
model.load_state_dict(state_dict)
#for param in model.parameters():
#    param.requires_grad = False
#for idx, m in enumerate(model.block1.modules()):
#    if idx == 4:
#        m.threshold1.requires_grad = True

if torch.cuda.is_available():
  model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=15,gamma = 0.7)

# %%
#Plot the initial learned distribution

for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
        
        thresh_hist = torch.histc(m.threshold1.data)
        start = np.min(m.threshold1.cpu().detach().numpy())
        end = np.max(m.threshold1.cpu().detach().numpy())
        xhist = torch.linspace(start,end,100) # histogram x-axis
        plt.plot(xhist, thresh_hist.cpu().detach().numpy())
        plt.title('Threshold tensor histogram before training')
        plt.ylabel('Count')
        plt.xlabel('Threshold layer values')

# %%
# ======================== Function to get the test accuracy ===============================================================================
def test():
  correct = 0
  total = 0
  model.train(False)
  with torch.no_grad():
    for i,(images,labels)in enumerate(testloader):
      if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
      outputs = model(Variable(images))
      labels = Variable(labels)
      _,predicted = outputs.max(1)
      total += labels.size(0)
      correct += (predicted.eq(labels)).sum().item()
    print('Test accuracy: %d %%' % (
  100 * correct / total))
  return 100*(correct/total)

#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 10 %
# 10.0
# Accuracy of plane :  0 %
# Accuracy of   car :  0 %
# Accuracy of  bird :  0 %
# Accuracy of   cat :  0 %
# Accuracy of  deer :  0 %
# Accuracy of   dog :  0 %
# Accuracy of  frog :  0 %
# Accuracy of horse :  0 %
# Accuracy of  ship :  0 %
# Accuracy of truck : 100 %

# %%
#Check if requires grad

for name, param in model.named_parameters():
    if param.requires_grad:
        #print('Yes')
        #print (name, param.data)
        print (name)
# Out:
# block1.0.weight
# block1.0.bias
# block1.1.weight
# block1.1.bias
# block1.3.weight
# block1.3.bias
# block1.3.threshold1
# block1.4.weight
# block1.4.bias
# block2.0.weight
# block2.0.bias
# block2.1.weight
# block2.1.bias
# block2.3.weight
# block2.3.bias
# block2.4.weight
# block2.4.bias
# block3.0.weight
# block3.0.bias
# block3.1.weight
# block3.1.bias
# block3.3.weight
# block3.3.bias
# block3.4.weight
# block3.4.bias
# block3.6.weight
# block3.6.bias
# block3.7.weight
# block3.7.bias
# block4.0.weight
# block4.0.bias
# block4.1.weight
# block4.1.bias
# block4.3.weight
# block4.3.bias
# block4.4.weight
# block4.4.bias
# block4.6.weight
# block4.6.bias
# block4.7.weight
# block4.7.bias
# block5.0.weight
# block5.0.bias
# block5.1.weight
# block5.1.bias
# block5.3.weight
# block5.3.bias
# block5.4.weight
# block5.4.bias
# block5.6.weight
# block5.6.bias
# block5.7.weight
# block5.7.bias
# fc.0.weight
# fc.0.bias
# fc.2.weight
# fc.2.bias
# fc.5.weight
# fc.5.bias

# %%
#Plot initial threshold distribution

for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
            
        fig2 = plt.figure()
        plt.figure(figsize=(15,15))
        plt.suptitle('Threshold tensor filter distributions before training', fontsize = 16)
        for idx2, filt  in enumerate(m.threshold1[0,:,:,:]):
            thresh_hist = torch.histc(filt)
            plt.subplot(8,8, idx2 + 1)
            plt.plot(xhist, thresh_hist.cpu().detach().numpy())

# %%
#before training
memorized = []
for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
        memorized = m.threshold1.clone()
        imgplot = plt.imshow(m.threshold1.cpu().detach().numpy()[0,1,:] - memorized.cpu().detach().numpy()[0,1,:])
        plt.colorbar()

# %%
#======================================================= Training =========================================================================
num_epochs = 100  # Train for 150 epochs
start_epoch = 0

total_step = len(trainloader)
train_loss = []  # Store the train_loss per epoch
test_accuracy = [] # Store the test_accuracy per epoch
for epoch in range(start_epoch,num_epochs+1):
  model.train(True)
  epoch_loss  = 0
  i_count = 0
  acc_total = 0
  for i,(images,labels) in enumerate(trainloader):
    if torch.cuda.is_available():
      images = images.cuda()
      labels = labels.cuda()
    labels = Variable(labels)
    optimizer.zero_grad()
    outputs = model(Variable(images))
    loss = criterion(outputs,labels)
    epoch_loss += loss.item()
    loss.backward()
    optimizer.step()
    _,predicted = outputs.max(1)
    denom = labels.size(0)
    correct = predicted.eq(labels).sum().item()
    acc = 100*(correct/denom)
    acc_total += acc
    i_count = i_count + 1
    
    #if(i%20 == 0):  # Print the loss per 20 iterations
      #print("Epoch: ",epoch," ","Iteration: ",i," loss: ",loss.item()," Train_iter Accuracy: ",acc)
  schedule.step()
  train_loss.append(epoch_loss)
  print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
  print('\n')
  test_acc = test()      # Print the test accuracy per epoch
  test_accuracy.append(test_acc)
  
  if(epoch%50 == 0):       # Save the model every 50 epoch
    state = {
        'model': model.state_dict(),
        'acc' : test_acc,
        'optim':optimizer.state_dict(),
        'epoch' : epoch
    }
    #path = './models/VGG16-flex-v5-block1-TEST-' + 'model_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
    #torch.save(state,path)
# Out:
# Epoch:  0   Loss:  1087.0303466320038   Train Accuracy : 17.794
#
#
# Test accuracy: 20 %
# Epoch:  1   Loss:  957.1161181926727   Train Accuracy : 26.668
#
#
# Test accuracy: 28 %
# Epoch:  2   Loss:  882.7839350700378   Train Accuracy : 33.214
#
#
# Test accuracy: 38 %
# Epoch:  3   Loss:  836.7118836641312   Train Accuracy : 37.89
#
#
# Test accuracy: 44 %
# Epoch:  4   Loss:  796.4182382822037   Train Accuracy : 41.854
#
#
# Test accuracy: 50 %
# Epoch:  5   Loss:  760.2172718048096   Train Accuracy : 45.96
#
#
# Test accuracy: 53 %
# Epoch:  6   Loss:  726.0997742414474   Train Accuracy : 49.11
#
#
# Test accuracy: 56 %
# Epoch:  7   Loss:  695.0972641706467   Train Accuracy : 52.02
#
#
# Test accuracy: 57 %
# Epoch:  8   Loss:  665.5076826810837   Train Accuracy : 54.442
#
#
# Test accuracy: 61 %
# Epoch:  9   Loss:  640.1856061220169   Train Accuracy : 56.93
#
#
# Test accuracy: 64 %
# Epoch:  10   Loss:  614.0921978354454   Train Accuracy : 59.278
#
#
# Test accuracy: 65 %
# Epoch:  11   Loss:  594.2235952019691   Train Accuracy : 60.73
#
#
# Test accuracy: 66 %
# Epoch:  12   Loss:  571.4166275858879   Train Accuracy : 62.46
#
#
# Test accuracy: 69 %
# Epoch:  13   Loss:  550.7342023253441   Train Accuracy : 64.614
#
#
# Test accuracy: 69 %
# Epoch:  14   Loss:  532.621119260788   Train Accuracy : 65.954
#
#
# Test accuracy: 72 %
# Epoch:  15   Loss:  503.4755249619484   Train Accuracy : 68.168
#
#
# Test accuracy: 72 %
# Epoch:  16   Loss:  488.6766366958618   Train Accuracy : 69.478
#
#
# Test accuracy: 74 %
# Epoch:  17   Loss:  474.89362663030624   Train Accuracy : 70.578
#
#
# Test accuracy: 76 %
# Epoch:  18   Loss:  462.857500910759   Train Accuracy : 71.586
#
#
# Test accuracy: 77 %
# Epoch:  19   Loss:  450.53153067827225   Train Accuracy : 72.61
#
#
# Test accuracy: 76 %
# Epoch:  20   Loss:  437.6405047774315   Train Accuracy : 73.418
#
#
# Test accuracy: 78 %
# Epoch:  21   Loss:  427.9099979400635   Train Accuracy : 74.51
#
#
# Test accuracy: 79 %
# Epoch:  22   Loss:  415.2502501010895   Train Accuracy : 75.276
#
#
# Test accuracy: 80 %
# Epoch:  23   Loss:  406.3982501029968   Train Accuracy : 76.326
#
#
# Test accuracy: 79 %
# Epoch:  24   Loss:  397.5986002087593   Train Accuracy : 76.798
#
#
# Test accuracy: 81 %
# Epoch:  25   Loss:  389.84519720077515   Train Accuracy : 77.522
#
#
# Test accuracy: 80 %
# Epoch:  26   Loss:  383.59134805202484   Train Accuracy : 78.026
#
#
# Test accuracy: 82 %
# Epoch:  27   Loss:  371.9657349586487   Train Accuracy : 78.786
#
#
# Test accuracy: 82 %
# Epoch:  28   Loss:  362.472010076046   Train Accuracy : 79.266
#
#
# Test accuracy: 82 %
# Epoch:  29   Loss:  359.63554361462593   Train Accuracy : 79.638
#
#
# Test accuracy: 82 %
# Epoch:  30   Loss:  336.3994776904583   Train Accuracy : 81.268
#
#
# Test accuracy: 84 %
# Epoch:  31   Loss:  323.0956770181656   Train Accuracy : 82.016
#
#
# Test accuracy: 84 %
# Epoch:  32   Loss:  318.76437774300575   Train Accuracy : 82.54
#
#
# Test accuracy: 84 %
# Epoch:  33   Loss:  310.51624459028244   Train Accuracy : 83.002
#
#
# Test accuracy: 84 %
# Epoch:  34   Loss:  308.91679188609123   Train Accuracy : 83.056
#
#
# Test accuracy: 84 %
# Epoch:  35   Loss:  301.21208572387695   Train Accuracy : 83.67
#
#
# Test accuracy: 84 %
# Epoch:  36   Loss:  298.1509556174278   Train Accuracy : 84.024
#
#
# Test accuracy: 84 %
# Epoch:  37   Loss:  294.40559834241867   Train Accuracy : 84.074
#
#
# Test accuracy: 84 %
# Epoch:  38   Loss:  287.3677128851414   Train Accuracy : 84.654
#
#
# Test accuracy: 84 %
# Epoch:  39   Loss:  286.47400134801865   Train Accuracy : 84.69
#
#
# Test accuracy: 85 %
# Epoch:  40   Loss:  279.8815026283264   Train Accuracy : 85.126
#
#
# Test accuracy: 85 %
# Epoch:  41   Loss:  278.3397667706013   Train Accuracy : 85.116
#
#
# Test accuracy: 85 %
# Epoch:  42   Loss:  272.71139764785767   Train Accuracy : 85.638
#
#
# Test accuracy: 84 %
# Epoch:  43   Loss:  269.20736971497536   Train Accuracy : 85.804
#
#
# Test accuracy: 85 %
# Epoch:  44   Loss:  263.8814545869827   Train Accuracy : 85.948
#
#
# Test accuracy: 86 %
# Epoch:  45   Loss:  246.85246032476425   Train Accuracy : 87.142
#
#
# Test accuracy: 87 %
# Epoch:  46   Loss:  238.38413164019585   Train Accuracy : 88.034
#
#
# Test accuracy: 87 %
# Epoch:  47   Loss:  235.006700694561   Train Accuracy : 88.142
#
#
# Test accuracy: 86 %
# Epoch:  48   Loss:  228.23582708835602   Train Accuracy : 88.514
#
#
# Test accuracy: 87 %
# Epoch:  49   Loss:  227.29398369789124   Train Accuracy : 88.602
#
#
# Test accuracy: 87 %
# Epoch:  50   Loss:  222.37623603641987   Train Accuracy : 88.864
#
#
# Test accuracy: 86 %
# Epoch:  51   Loss:  221.78656986355782   Train Accuracy : 88.91
#
#
# Test accuracy: 87 %
# Epoch:  52   Loss:  217.5805124938488   Train Accuracy : 89.172
#
#
# Test accuracy: 87 %
# Epoch:  53   Loss:  215.46346235275269   Train Accuracy : 89.652
#
#
# Test accuracy: 86 %
# Epoch:  54   Loss:  211.16063451766968   Train Accuracy : 89.542
#
#
# Test accuracy: 87 %
# Epoch:  55   Loss:  208.84690243005753   Train Accuracy : 89.772
#
#
# Test accuracy: 87 %
# Epoch:  56   Loss:  207.14184601604939   Train Accuracy : 89.808
#
#
# Test accuracy: 88 %
# Epoch:  57   Loss:  204.95061883330345   Train Accuracy : 89.896
#
#
# Test accuracy: 87 %
# Epoch:  58   Loss:  202.883276745677   Train Accuracy : 90.1
#
#
# Test accuracy: 87 %
# Epoch:  59   Loss:  202.16621816158295   Train Accuracy : 90.156
#
#
# Test accuracy: 87 %
# Epoch:  60   Loss:  185.56278854608536   Train Accuracy : 91.316
#
#
# Test accuracy: 88 %
# Epoch:  61   Loss:  179.52731597423553   Train Accuracy : 91.73
#
#
# Test accuracy: 88 %
# Epoch:  62   Loss:  176.05429980158806   Train Accuracy : 91.906
#
#
# Test accuracy: 88 %
# Epoch:  63   Loss:  173.62451165914536   Train Accuracy : 92.188
#
#
# Test accuracy: 88 %
# Epoch:  64   Loss:  170.66144473850727   Train Accuracy : 92.256
#
#
# Test accuracy: 88 %
# Epoch:  65   Loss:  165.58492475748062   Train Accuracy : 92.608
#
#
# Test accuracy: 88 %
# Epoch:  66   Loss:  167.03352856636047   Train Accuracy : 92.588
#
#
# Test accuracy: 88 %
# Epoch:  67   Loss:  164.3901515007019   Train Accuracy : 92.684
#
#
# Test accuracy: 88 %
# Epoch:  68   Loss:  161.34872125089169   Train Accuracy : 92.792
#
#
# Test accuracy: 88 %
# Epoch:  69   Loss:  161.96898253262043   Train Accuracy : 92.76
#
#
# Test accuracy: 88 %
# Epoch:  70   Loss:  160.2196270674467   Train Accuracy : 93.024
#
#
# Test accuracy: 88 %
# Epoch:  71   Loss:  154.67824985086918   Train Accuracy : 93.292
#
#
# Test accuracy: 88 %
# Epoch:  72   Loss:  157.93611998856068   Train Accuracy : 93.118
#
#
# Test accuracy: 88 %
# Epoch:  73   Loss:  156.86899872124195   Train Accuracy : 93.152
#
#
# Test accuracy: 87 %
# Epoch:  74   Loss:  152.0596228837967   Train Accuracy : 93.474
#
#
# Test accuracy: 88 %
# Epoch:  75   Loss:  142.8223472982645   Train Accuracy : 94.138
#
#
# Test accuracy: 88 %
# Epoch:  76   Loss:  133.94011107087135   Train Accuracy : 94.562
#
#
# Test accuracy: 88 %
# Epoch:  77   Loss:  131.7369464635849   Train Accuracy : 94.734
#
#
# Test accuracy: 88 %
# Epoch:  78   Loss:  129.4166692942381   Train Accuracy : 94.89
#
#
# Test accuracy: 88 %
# Epoch:  79   Loss:  127.79891467094421   Train Accuracy : 95.07
#
#
# Test accuracy: 88 %
# Epoch:  80   Loss:  127.16710162162781   Train Accuracy : 95.004
#
#
# Test accuracy: 89 %
# Epoch:  81   Loss:  127.4872125685215   Train Accuracy : 94.99
#
#
# Test accuracy: 88 %
# Epoch:  82   Loss:  120.71613685786724   Train Accuracy : 95.484
#
#
# Test accuracy: 89 %
# Epoch:  83   Loss:  119.94241963326931   Train Accuracy : 95.536
#
#
# Test accuracy: 89 %
# Epoch:  84   Loss:  121.47292972356081   Train Accuracy : 95.382
#
#
# Test accuracy: 88 %
# Epoch:  85   Loss:  117.68431245535612   Train Accuracy : 95.648
#
#
# Test accuracy: 88 %
# Epoch:  86   Loss:  118.53418975323439   Train Accuracy : 95.574
#
#
# Test accuracy: 89 %
# Epoch:  87   Loss:  118.94490365684032   Train Accuracy : 95.508
#
#
# Test accuracy: 89 %
# Epoch:  88   Loss:  118.11945897340775   Train Accuracy : 95.612
#
#
# Test accuracy: 88 %
# Epoch:  89   Loss:  117.26219944655895   Train Accuracy : 95.624
#
#
# Test accuracy: 89 %
# Epoch:  90   Loss:  110.22228115797043   Train Accuracy : 96.088
#
#
# Test accuracy: 89 %
# Epoch:  91   Loss:  106.58809312433004   Train Accuracy : 96.378
#
#
# Test accuracy: 89 %
# Epoch:  92   Loss:  102.5392392128706   Train Accuracy : 96.538
#
#
# Test accuracy: 89 %
# Epoch:  93   Loss:  98.77722633630037   Train Accuracy : 96.832
#
#
# Test accuracy: 89 %
# Epoch:  94   Loss:  98.37051101773977   Train Accuracy : 96.79
#
#
# Test accuracy: 89 %
# Epoch:  95   Loss:  98.11347024142742   Train Accuracy : 96.89
# Test accuracy: 89 %
# Epoch:  96   Loss:  97.19588515162468   Train Accuracy : 96.946
#
#
# Test accuracy: 89 %
# Epoch:  97   Loss:  94.60728552937508   Train Accuracy : 97.048
#
#
# Test accuracy: 89 %
# Epoch:  98   Loss:  94.99775080382824   Train Accuracy : 96.954
#
#
# Test accuracy: 89 %
# Epoch:  99   Loss:  92.28560128808022   Train Accuracy : 97.13
#
#
# Test accuracy: 89 %
# Epoch:  100   Loss:  93.57805984467268   Train Accuracy : 97.04
#
#
# Test accuracy: 89 %

# %%
#after training
for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
        imgplot = plt.imshow(m.threshold1.cpu().detach().numpy()[0,1,:] - memorized.cpu().detach().numpy()[0,1,:])
        plt.colorbar()

# %%
#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 89 %
# 89.16
# Accuracy of plane : 95 %
# Accuracy of   car : 96 %
# Accuracy of  bird : 84 %
# Accuracy of   cat : 67 %
# Accuracy of  deer : 87 %
# Accuracy of   dog : 87 %
# Accuracy of  frog : 94 %
# Accuracy of horse : 93 %
# Accuracy of  ship : 97 %
# Accuracy of truck : 100 %

# %%
#Plot the new learned distribution

for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
        
        thresh_hist = torch.histc(m.threshold1)
        start = np.min(m.threshold1.cpu().detach().numpy())
        end = np.max(m.threshold1.cpu().detach().numpy())
        xhist = torch.linspace(start,end,100) # histogram x-axis
        plt.plot(xhist, thresh_hist.cpu().detach().numpy())
        plt.title('Threshold tensor histogram after training')
        plt.ylabel('Count')
        plt.xlabel('Threshold layer values')

# %%
#Plot after training threshold distributions

for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
            
        fig2 = plt.figure()
        plt.figure(figsize=(15,15))
        plt.suptitle('Threshold tensor filter distributions before training', fontsize = 16)
        for idx2, filt  in enumerate(m.threshold1[0,:,:,:]):
            thresh_hist = torch.histc(filt)
            plt.subplot(8,8, idx2 + 1)
            plt.plot(xhist, thresh_hist.cpu().detach().numpy())
