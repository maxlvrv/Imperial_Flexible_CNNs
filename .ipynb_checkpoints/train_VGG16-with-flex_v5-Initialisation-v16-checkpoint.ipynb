# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

from models.VGG16_with_flex_v8 import *


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
#   car   car  ship plane

# %%
# =============================================================== Model initialisation, Loss function and Optimizer =====================================
model = VGG16()
# Load the pretrained model
state = torch.load('./models/VGG16-flex-v5-block1-TEST-model_20_78.pth')
model.load_state_dict(state['model'])
#state_dict = model.state_dict()
#thr = state_dict["block1.3.threshold1"]
#state_dict["block1.3.threshold1"] = Variable(thr.data.new(1, 64, 30, 30).normal_(0.5,0)) # make a random tensor of same type and device as original
#model.load_state_dict(state_dict)
for param in model.parameters():
    param.requires_grad = False
for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
        m.threshold1.requires_grad = True

if torch.cuda.is_available():
  model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=80,gamma = 0.7)

# %%
#Plot the initial learned distribution

for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
        
        thresh_hist = torch.histc(m.threshold1.data)
        start = np.min(m.threshold1.cpu().detach().numpy())
        end = np.max(m.threshold1.cpu().detach().numpy())
        xhist = torch.linspace(start,end,100) # histogram x-axis
        plt.plot(xhist, thresh_hist.cpu().detach().numpy())
        plt.title('Threshold tensor histogram before training')
        plt.ylabel('Count')
        plt.xlabel('Threshold layer values')

# %%
# ======================== Function to get the test accuracy ===============================================================================
def test():
  correct = 0
  total = 0
  model.train(False)
  with torch.no_grad():
    for i,(images,labels)in enumerate(testloader):
      if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
      outputs = model(Variable(images))
      labels = Variable(labels)
      _,predicted = outputs.max(1)
      total += labels.size(0)
      correct += (predicted.eq(labels)).sum().item()
    print('Test accuracy: %d %%' % (
  100 * correct / total))
  return 100*(correct/total)

#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 78 %
# 78.64
# Accuracy of plane : 93 %
# Accuracy of   car : 84 %
# Accuracy of  bird : 60 %
# Accuracy of   cat : 58 %
# Accuracy of  deer : 71 %
# Accuracy of   dog : 68 %
# Accuracy of  frog : 92 %
# Accuracy of horse : 87 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 89 %

# %%
#Check if requires grad

for name, param in model.named_parameters():
    if param.requires_grad:
        #print('Yes')
        #print (name, param.data)
        print (name)
# Out:
# block1.3.threshold1

# %%
#Plot initial threshold distribution

for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
            
        fig2 = plt.figure()
        plt.figure(figsize=(15,15))
        plt.suptitle('Threshold tensor filter distributions before training', fontsize = 16)
        for idx2, filt  in enumerate(m.threshold1[0,:,:,:]):
            thresh_hist = torch.histc(filt)
            plt.subplot(8,8, idx2 + 1)
            plt.plot(xhist, thresh_hist.cpu().detach().numpy())

# %%
#before training
memorized = []
for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
        memorized = m.threshold1.clone()
        imgplot = plt.imshow(m.threshold1.cpu().detach().numpy()[0,1,:] - memorized.cpu().detach().numpy()[0,1,:])
        plt.colorbar()

# %%
#======================================================= Training =========================================================================
num_epochs = 1000 # Train for 150 epochs
start_epoch = 0

total_step = len(trainloader)
train_loss = []  # Store the train_loss per epoch
test_accuracy = [] # Store the test_accuracy per epoch
for epoch in range(start_epoch,num_epochs+1):
  model.train(True)
  epoch_loss  = 0
  i_count = 0
  acc_total = 0
  for i,(images,labels) in enumerate(trainloader):
    if torch.cuda.is_available():
      images = images.cuda()
      labels = labels.cuda()
    labels = Variable(labels)
    optimizer.zero_grad()
    outputs = model(Variable(images))
    loss = criterion(outputs,labels)
    epoch_loss += loss.item()
    loss.backward()
    optimizer.step()
    _,predicted = outputs.max(1)
    denom = labels.size(0)
    correct = predicted.eq(labels).sum().item()
    acc = 100*(correct/denom)
    acc_total += acc
    i_count = i_count + 1
    
    #if(i%20 == 0):  # Print the loss per 20 iterations
      #print("Epoch: ",epoch," ","Iteration: ",i," loss: ",loss.item()," Train_iter Accuracy: ",acc)
  schedule.step()
  train_loss.append(epoch_loss)
  print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
  print('\n')
  test_acc = test()      # Print the test accuracy per epoch
  test_accuracy.append(test_acc)
  
  if(epoch%250 == 0):       # Save the model every 50 epoch
    state = {
        'model': model.state_dict(),
        'acc' : test_acc,
        'optim':optimizer.state_dict(),
        'epoch' : epoch
    }
    path = './models/VGG16-flex-v5-block1-TEST-1000-' + 'model_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
    torch.save(state,path)
# Out:
# Epoch:  0   Loss:  428.52351599931717   Train Accuracy : 74.356
#
#
# Test accuracy: 78 %
# Epoch:  1   Loss:  425.05626851320267   Train Accuracy : 74.41
#
#
# Test accuracy: 78 %
# Epoch:  2   Loss:  426.7736471295357   Train Accuracy : 74.342
#
#
# Test accuracy: 78 %
# Epoch:  3   Loss:  425.17092448472977   Train Accuracy : 74.424
#
#
# Test accuracy: 78 %
# Epoch:  4   Loss:  427.4070554971695   Train Accuracy : 74.484
#
#
# Test accuracy: 78 %
# Epoch:  5   Loss:  425.18001222610474   Train Accuracy : 74.506
#
#
# Test accuracy: 78 %
# Epoch:  6   Loss:  428.74866342544556   Train Accuracy : 74.24
#
#
# Test accuracy: 78 %
# Epoch:  7   Loss:  429.6240876317024   Train Accuracy : 74.03
# Epoch:  217   Loss:  428.0600699186325   Train Accuracy : 74.202
#
#
# Test accuracy: 78 %
# Epoch:  218   Loss:  427.7685162425041   Train Accuracy : 74.254
#
#
# Test accuracy: 78 %
# Epoch:  219   Loss:  433.1609801054001   Train Accuracy : 73.94
#
#
# Test accuracy: 78 %
# Epoch:  220   Loss:  428.0992026925087   Train Accuracy : 74.44
#
#
# Test accuracy: 78 %
# Epoch:  221   Loss:  427.6253539919853   Train Accuracy : 74.376
#
#
# Test accuracy: 78 %
# Epoch:  222   Loss:  429.7081011533737   Train Accuracy : 74.15
#
#
# Test accuracy: 78 %
# Epoch:  223   Loss:  428.285419523716   Train Accuracy : 74.336
#
#
# Test accuracy: 78 %
# Epoch:  224   Loss:  428.3381618261337   Train Accuracy : 74.114
#
#
# Test accuracy: 78 %
# Epoch:  225   Loss:  428.28669995069504   Train Accuracy : 73.994
#
#
# Test accuracy: 78 %
# Epoch:  226   Loss:  428.83426171541214   Train Accuracy : 74.186
#
#
# Test accuracy: 78 %
# Epoch:  227   Loss:  429.3643280863762   Train Accuracy : 74.13
#
#
# Test accuracy: 78 %
# Epoch:  228   Loss:  430.1876631975174   Train Accuracy : 74.124
#
#
# Test accuracy: 78 %
# Epoch:  229   Loss:  427.45534217357635   Train Accuracy : 74.264
#
#
# Test accuracy: 78 %
# Epoch:  230   Loss:  430.4133498072624   Train Accuracy : 74.1
#
#
# Test accuracy: 78 %
# Epoch:  231   Loss:  431.3877018690109   Train Accuracy : 74.056
#
#
# Test accuracy: 78 %
# Epoch:  232   Loss:  428.7446628212929   Train Accuracy : 74.174
#
#
# Test accuracy: 78 %
# Epoch:  233   Loss:  428.4599087834358   Train Accuracy : 74.298
#
#
# Test accuracy: 78 %
# Epoch:  234   Loss:  431.6211282014847   Train Accuracy : 74.112
#
#
# Test accuracy: 78 %
# Epoch:  235   Loss:  427.6643388271332   Train Accuracy : 74.378
#
#
# Test accuracy: 78 %
# Epoch:  236   Loss:  429.85059463977814   Train Accuracy : 74.252
#
#
# Test accuracy: 78 %
# Epoch:  237   Loss:  428.29936027526855   Train Accuracy : 74.44
#
#
# Test accuracy: 78 %
# Epoch:  238   Loss:  429.9381998181343   Train Accuracy : 74.244
#
#
# Test accuracy: 78 %
# Epoch:  239   Loss:  430.1925826072693   Train Accuracy : 74.046
#
#
# Test accuracy: 78 %
# Epoch:  240   Loss:  428.7362726330757   Train Accuracy : 74.078
#
#
# Test accuracy: 78 %
# Epoch:  241   Loss:  429.53192204236984   Train Accuracy : 73.846
#
#
# Test accuracy: 78 %
# Epoch:  242   Loss:  429.17050421237946   Train Accuracy : 74.13
#
#
# Test accuracy: 78 %
# Epoch:  243   Loss:  432.6232480406761   Train Accuracy : 74.2
#
#
# Test accuracy: 78 %
# Epoch:  244   Loss:  427.01463413238525   Train Accuracy : 74.404
#
#
# Test accuracy: 78 %
# Epoch:  245   Loss:  431.5107927918434   Train Accuracy : 74.05
#
#
# Test accuracy: 78 %
# Epoch:  246   Loss:  428.4841464161873   Train Accuracy : 74.196
#
#
# Test accuracy: 78 %
# Epoch:  247   Loss:  428.9655953645706   Train Accuracy : 74.406
#
#
# Test accuracy: 78 %
# Epoch:  248   Loss:  430.4727991223335   Train Accuracy : 74.176
#
#
# Test accuracy: 78 %
# Epoch:  249   Loss:  431.17511558532715   Train Accuracy : 74.27
#
#
# Test accuracy: 78 %
# Epoch:  250   Loss:  428.3612847328186   Train Accuracy : 74.078
#
#
# Test accuracy: 78 %
# Epoch:  251   Loss:  429.2835605144501   Train Accuracy : 74.28
#
#
# Test accuracy: 78 %
# Epoch:  252   Loss:  427.9440969824791   Train Accuracy : 74.064
#
#
# Test accuracy: 78 %
# Epoch:  253   Loss:  430.1992990374565   Train Accuracy : 74.202
#
#
# Test accuracy: 78 %
# Epoch:  254   Loss:  429.08230459690094   Train Accuracy : 74.254
#
#
# Test accuracy: 78 %
# Epoch:  255   Loss:  432.23144817352295   Train Accuracy : 73.972
#
#
# Test accuracy: 78 %
# Epoch:  256   Loss:  428.3879096508026   Train Accuracy : 74.084
#
#
# Test accuracy: 78 %
# Epoch:  257   Loss:  430.6260875463486   Train Accuracy : 74.136
#
#
# Test accuracy: 78 %
# Epoch:  258   Loss:  429.35950756073   Train Accuracy : 74.286
#
#
# Test accuracy: 78 %
# Epoch:  259   Loss:  429.01606327295303   Train Accuracy : 74.1
#
#
# Test accuracy: 78 %
# Epoch:  260   Loss:  428.5461329817772   Train Accuracy : 74.092
#
#
# Test accuracy: 78 %
# Epoch:  261   Loss:  429.89854365587234   Train Accuracy : 74.13
#
#
# Test accuracy: 78 %
# Epoch:  262   Loss:  430.2633413672447   Train Accuracy : 73.96
#
#
# Test accuracy: 78 %
# Epoch:  263   Loss:  429.214018702507   Train Accuracy : 74.284
#
#
# Test accuracy: 78 %
# Epoch:  264   Loss:  429.97690534591675   Train Accuracy : 74.186
#
#
# Test accuracy: 78 %
# Epoch:  265   Loss:  430.4460188150406   Train Accuracy : 73.984
#
#
# Test accuracy: 78 %
# Epoch:  266   Loss:  428.53657698631287   Train Accuracy : 74.33
#
#
# Test accuracy: 78 %
# Epoch:  267   Loss:  429.2003125548363   Train Accuracy : 74.15
#
#
# Test accuracy: 78 %
# Epoch:  268   Loss:  427.8079876899719   Train Accuracy : 73.988
#
#
# Test accuracy: 78 %
# Epoch:  269   Loss:  428.66096246242523   Train Accuracy : 74.16
#
#
# Test accuracy: 78 %
# Epoch:  270   Loss:  431.6223071217537   Train Accuracy : 74.068
#
#
# Test accuracy: 78 %
# Epoch:  271   Loss:  430.94545888900757   Train Accuracy : 73.998
#
#
# Test accuracy: 78 %
# Epoch:  272   Loss:  430.48811888694763   Train Accuracy : 74.04
#
#
# Test accuracy: 78 %
# Epoch:  273   Loss:  430.36720752716064   Train Accuracy : 74.222
#
#
# Test accuracy: 78 %
# Epoch:  274   Loss:  429.44710898399353   Train Accuracy : 74.144
#
#
# Test accuracy: 78 %
# Epoch:  275   Loss:  430.9330983161926   Train Accuracy : 74.194
#
#
# Test accuracy: 78 %
# Epoch:  276   Loss:  430.2354093194008   Train Accuracy : 74.01
#
#
# Test accuracy: 78 %
# Epoch:  277   Loss:  428.58908319473267   Train Accuracy : 73.986
#
#
# Test accuracy: 78 %
# Epoch:  278   Loss:  428.2996107339859   Train Accuracy : 74.232
#
#
# Test accuracy: 78 %
# Epoch:  279   Loss:  430.76170748472214   Train Accuracy : 74.168
#
#
# Test accuracy: 78 %
# Epoch:  280   Loss:  430.286593914032   Train Accuracy : 74.194
#
#
# Test accuracy: 78 %
# Epoch:  281   Loss:  429.8830933570862   Train Accuracy : 74.088
#
#
# Test accuracy: 78 %
# Epoch:  282   Loss:  429.71217000484467   Train Accuracy : 73.948
#
#
# Test accuracy: 78 %
# Epoch:  283   Loss:  428.33343982696533   Train Accuracy : 74.356
#
#
# Test accuracy: 78 %
# Epoch:  284   Loss:  428.71769362688065   Train Accuracy : 74.314
#
#
# Test accuracy: 78 %
# Epoch:  285   Loss:  428.9081320762634   Train Accuracy : 74.13
#
#
# Test accuracy: 78 %
# Epoch:
Train Accuracy : 74.184
#
#
# Test accuracy: 78 %
# Epoch:  827   Loss:  428.9779891371727   Train Accuracy : 74.172
#
#
# Test accuracy: 78 %
# Epoch:  828   Loss:  430.1336490511894   Train Accuracy : 74.152
#
#
# Test accuracy: 78 %
# Epoch:  829   Loss:  428.91203236579895   Train Accuracy : 74.06
#
#
# Test accuracy: 78 %
# Epoch:  830   Loss:  427.76329827308655   Train Accuracy : 74.246
#
#
# Test accuracy: 78 %
# Epoch:  831   Loss:  430.08722227811813   Train Accuracy : 74.172
#
#
# Test accuracy: 78 %
# Epoch:  832   Loss:  427.5295355319977   Train Accuracy : 74.454
#
#
# Test accuracy: 78 %
# Epoch:  833   Loss:  427.7635678052902   Train Accuracy : 74.194
#
#
# Test accuracy: 78 %
# Epoch:  834   Loss:  428.40892696380615   Train Accuracy : 74.252
#
#
# Test accuracy: 78 %
# Epoch:  835   Loss:  428.5099803209305   Train Accuracy : 74.334
#
#
# Test accuracy: 78 %
# Epoch:  836   Loss:  428.9662374854088   Train Accuracy : 74.164
#
#
# Test accuracy: 78 %
# Epoch:  837   Loss:  429.3261252641678   Train Accuracy : 74.05
#
#
# Test accuracy: 78 %
# Epoch:  838   Loss:  428.2517327070236   Train Accuracy : 74.346
#
#
# Test accuracy: 78 %
# Epoch:  839   Loss:  428.9487571120262   Train Accuracy : 74.312
#
#
# Test accuracy: 78 %
# Epoch:  840   Loss:  429.47603303194046   Train Accuracy : 73.902
#
#
# Test accuracy: 78 %
# Epoch:  841   Loss:  425.8792145252228   Train Accuracy : 74.414
#
#
# Test accuracy: 78 %
# Epoch:  842   Loss:  429.2828965783119   Train Accuracy : 74.484
#
#
# Test accuracy: 78 %
# Epoch:  843   Loss:  428.85136461257935   Train Accuracy : 74.326
#
#
# Test accuracy: 78 %
# Epoch:  844   Loss:  429.4331588149071   Train Accuracy : 74.374
#
#
# Test accuracy: 78 %
# Epoch:  845   Loss:  432.13226330280304   Train Accuracy : 73.97
#
#
# Test accuracy: 78 %
# Epoch:  846   Loss:  429.73644173145294   Train Accuracy : 74.234
#
#
# Test accuracy: 78 %
# Epoch:  847   Loss:  428.7376827597618   Train Accuracy : 74.386
#
#
# Test accuracy: 78 %
# Epoch:  848   Loss:  430.46304458379745   Train Accuracy : 74.024
#
#
# Test accuracy: 78 %
# Epoch:  849   Loss:  433.09051662683487   Train Accuracy : 73.922
#
#
# Test accuracy: 78 %
# Epoch:  850   Loss:  430.24681013822556   Train Accuracy : 74.124
#
#
# Test accuracy: 78 %
# Epoch:  851   Loss:  430.760402739048   Train Accuracy : 74.062
#
#
# Test accuracy: 78 %
# Epoch:  852   Loss:  429.33072233200073   Train Accuracy : 74.0
#
#
# Test accuracy: 78 %
# Epoch:  853   Loss:  430.0941458940506   Train Accuracy : 74.174
#
#
# Test accuracy: 78 %
# Epoch:  854   Loss:  426.919864654541   Train Accuracy : 74.21
#
#
# Test accuracy: 78 %
# Epoch:  855   Loss:  429.60452431440353   Train Accuracy : 74.088
#
#
# Test accuracy: 78 %
# Epoch:  856   Loss:  429.69766879081726   Train Accuracy : 74.068
#
#
# Test accuracy: 78 %
# Epoch:  857   Loss:  428.31968623399734   Train Accuracy : 74.23
#
#
# Test accuracy: 78 %
# Epoch:  858   Loss:  428.9417932629585   Train Accuracy : 74.132
#
#
# Test accuracy: 78 %
# Epoch:  859   Loss:  428.7973085641861   Train Accuracy : 74.28
#
#
# Test accuracy: 78 %
# Epoch:
Train Accuracy : 74.28
#
#
# Test accuracy: 78 %
# Epoch:  890   Loss:  428.58086037635803   Train Accuracy : 74.228
#
#
# Test accuracy: 78 %
# Epoch:  891   Loss:  429.8918445110321   Train Accuracy : 73.966
#
#
# Test accuracy: 78 %
# Epoch:  892   Loss:  430.3555203676224   Train Accuracy : 74.376
#
#
# Test accuracy: 78 %
# Epoch:  893   Loss:  431.1049265861511   Train Accuracy : 74.022
#
#
# Test accuracy: 78 %
# Epoch:  894   Loss:  429.8593499660492   Train Accuracy : 74.226
#
#
# Test accuracy: 78 %
# Epoch:  895   Loss:  429.2586173415184   Train Accuracy : 73.982
#
#
# Test accuracy: 78 %
# Epoch:  896   Loss:  429.99581319093704   Train Accuracy : 74.002
#
#
# Test accuracy: 78 %
# Epoch:  897   Loss:  430.46226954460144   Train Accuracy : 74.286
#
#
# Test accuracy: 78 %
# Epoch:  898   Loss:  429.03720259666443   Train Accuracy : 74.366
#
#
# Test accuracy: 78 %
# Epoch:  899   Loss:  429.6482564806938   Train Accuracy : 74.214
#
#
# Test accuracy: 78 %
# Epoch:  900   Loss:  429.74499702453613   Train Accuracy : 74.184
#
#
# Test accuracy: 78 %
# Epoch:  901   Loss:  429.92447596788406   Train Accuracy : 73.982
#
#
# Test accuracy: 78 %
# Epoch:  902   Loss:  430.2713974118233   Train Accuracy : 74.082
#
#
# Test accuracy: 78 %
# Epoch:  903   Loss:  428.53944689035416   Train Accuracy : 74.116
#
#
# Test accuracy: 78 %
# Epoch:  904   Loss:  428.1805482506752   Train Accuracy : 74.196
#
#
# Test accuracy: 78 %
# Epoch:  905   Loss:  428.3627141714096   Train Accuracy : 74.204
#
#
# Test accuracy: 78 %
# Epoch:  906   Loss:  429.2454162836075   Train Accuracy : 74.078
#
#
# Test accuracy: 78 %
# Epoch:  907   Loss:  427.31349486112595   Train Accuracy : 74.298
#
#
# Test accuracy: 78 %
# Epoch:  908   Loss:  430.6311143040657   Train Accuracy : 74.016
#
#
# Test accuracy: 78 %
# Epoch:  909   Loss:  427.00087147951126   Train Accuracy : 74.132
#
#
# Test accuracy: 78 %
# Epoch:  910   Loss:  431.39336973428726   Train Accuracy : 74.016
#
#
# Test accuracy: 78 %
# Epoch:  911   Loss:  427.12047654390335   Train Accuracy : 74.356
#
#
# Test accuracy: 78 %
# Epoch:  912   Loss:  428.3907486796379   Train Accuracy : 74.39
#
#
# Test accuracy: 78 %
# Epoch:  913   Loss:  431.8597646355629   Train Accuracy : 73.968
#
#
# Test accuracy: 78 %
# Epoch:  914   Loss:  428.7130674123764   Train Accuracy : 74.206
#
#
# Test accuracy: 78 %
# Epoch:  915   Loss:  429.8168592453003   Train Accuracy : 74.208
#
#
# Test accuracy: 78 %
# Epoch:  916   Loss:  431.1683951020241   Train Accuracy : 74.078
#
#
# Test accuracy: 78 %
# Epoch:  917   Loss:  427.1230768561363   Train Accuracy : 74.042
#
#
# Test accuracy: 78 %
# Epoch:  918   Loss:  429.95181834697723   Train Accuracy : 74.19
#
#
# Test accuracy: 78 %
# Epoch:  919   Loss:  429.3279297351837   Train Accuracy : 74.154
#
#
# Test accuracy: 78 %
# Epoch:  920   Loss:  432.75165981054306   Train Accuracy : 73.928
#
#
# Test accuracy: 78 %
# Epoch:  921   Loss:  426.9345641732216   Train Accuracy : 74.422
#
#
# Test accuracy: 78 %
# Epoch:  922   Loss:  429.43006294965744   Train Accuracy : 74.252
#
#
# Test accuracy: 78 %
# Epoch:  923   Loss:  431.495188832283   Train Accuracy : 73.93
#
#
# Test accuracy: 78 %
# Epoch:  924   Loss:  429.39750450849533   Train Accuracy : 74.19
#
#
# Test accuracy: 78 %
# Epoch:  925   Loss:  428.48315167427063   Train Accuracy : 74.11
#
#
# Test accuracy: 78 %
# Epoch:  926   Loss:  429.55472284555435   Train Accuracy : 74.084
#
#
# Test accuracy: 78 %
# Epoch:  927   Loss:  430.4106473326683   Train Accuracy : 74.092
#
#
# Test accuracy: 78 %
# Epoch:  928   Loss:  427.255089700222   Train Accuracy : 74.086
#
#
# Test accuracy: 78 %
# Epoch:  929   Loss:  427.79821622371674   Train Accuracy : 74.286
#
#
# Test accuracy: 78 %
# Epoch:  930   Loss:  430.44490283727646   Train Accuracy : 74.192
#
#
# Test accuracy: 78 %
# Epoch:  931   Loss:  430.4529989361763   Train Accuracy : 74.214
#
#
# Test accuracy: 78 %
# Epoch:  932   Loss:  430.0377140045166   Train Accuracy : 74.062
#
#
# Test accuracy: 78 %
# Epoch:  933   Loss:  429.54650604724884   Train Accuracy : 74.15
#
#
# Test accuracy: 78 %
# Epoch:  934   Loss:  427.7976056933403   Train Accuracy : 74.264
#
#
# Test accuracy: 78 %
# Epoch:  935   Loss:  428.1036242842674   Train Accuracy : 74.368
#
#
# Test accuracy: 78 %
# Epoch:  936   Loss:  428.6852622628212   Train Accuracy : 74.266
#
#
# Test accuracy: 78 %
# Epoch:  937   Loss:  431.16239070892334   Train Accuracy : 73.89
#
#
# Test accuracy: 78 %
# Epoch:  938   Loss:  428.15404456853867   Train Accuracy : 74.086
#
#
# Test accuracy: 78 %
# Epoch:  939   Loss:  429.96309423446655   Train Accuracy : 74.23
#
#
# Test accuracy: 78 %
# Epoch:  940   Loss:  428.8457502126694   Train Accuracy : 74.078
#
#
# Test accuracy: 78 %
# Epoch:  941   Loss:  431.69217973947525   Train Accuracy : 74.116
#
#
# Test accuracy: 78 %
# Epoch:  942   Loss:  432.7421734929085   Train Accuracy : 73.92
#
#
# Test accuracy: 78 %
# Epoch:  943   Loss:  427.9637825489044   Train Accuracy : 74.066
#
#
# Test accuracy: 78 %
# Epoch:  944   Loss:  428.07527339458466   Train Accuracy : 74.242
#
#
# Test accuracy: 78 %
# Epoch:  945   Loss:  431.61042881011963   Train Accuracy : 74.18
#
#
# Test accuracy: 78 %
# Epoch:  946   Loss:  426.75205117464066   Train Accuracy : 74.51
#
#
# Test accuracy: 78 %
# Epoch:  947   Loss:  428.536548435688   Train Accuracy : 74.034
#
#
# Test accuracy: 78 %
# Epoch:  948   Loss:  431.2882894873619   Train Accuracy : 74.056
#
#
# Test accuracy: 78 %
# Epoch:  949   Loss:  428.08166444301605   Train Accuracy : 74.154
#
#
# Test accuracy: 78 %
# Epoch:  950   Loss:  431.3165118098259   Train Accuracy : 73.984
#
#
# Test accuracy: 78 %
# Epoch:  951   Loss:  427.5228680372238   Train Accuracy : 74.32
#
#
# Test accuracy: 78 %
# Epoch:  952   Loss:  429.4231225848198   Train Accuracy : 74.14
#
#
# Test accuracy: 78 %
# Epoch:  953   Loss:  433.21420669555664   Train Accuracy : 74.018
#
#
# Test accuracy: 78 %
# Epoch:  954   Loss:  426.1564394235611   Train Accuracy : 74.57
#
#
# Test accuracy: 78 %
# Epoch:  955   Loss:  431.2497843503952   Train Accuracy : 74.066
#
#
# Test accuracy: 78 %
# Epoch:  956   Loss:  427.12182825803757   Train Accuracy : 74.2
#
#
# Test accuracy: 78 %
# Epoch:  957   Loss:  429.20985996723175   Train Accuracy : 74.354
#
#
# Test accuracy: 78 %
# Epoch:  958   Loss:  426.86446475982666   Train Accuracy : 74.504
#
#
# Test accuracy: 78 %
# Epoch:  959   Loss:  426.9340617656708   Train Accuracy : 74.346
#
#
# Test accuracy: 78 %
# Epoch:  960   Loss:  429.28803646564484   Train Accuracy : 74.232
#
#
# Test accuracy: 78 %
# Epoch:  961   Loss:  428.61285215616226   Train Accuracy : 74.264
#
#
# Test accuracy: 78 %
# Epoch:  962   Loss:  429.1452826857567   Train Accuracy : 74.17
#
#
# Test accuracy: 78 %
# Epoch:  963   Loss:  430.7706363797188   Train Accuracy : 74.17
#
#
# Test accuracy: 78 %
# Epoch:  964   Loss:  429.78807705640793   Train Accuracy : 74.164
#
#
# Test accuracy: 78 %
# Epoch:  965   Loss:  429.91528075933456   Train Accuracy : 74.022
#
#
# Test accuracy: 78 %
# Epoch:  966   Loss:  427.93431520462036   Train Accuracy : 74.158
#
#
# Test accuracy: 78 %
# Epoch:  967   Loss:  428.8259217739105   Train Accuracy : 74.37
#
#
# Test accuracy: 78 %
# Epoch:  968   Loss:  430.9690346121788   Train Accuracy : 73.91
#
#
# Test accuracy: 78 %
# Epoch:  969   Loss:  431.4806745648384   Train Accuracy : 74.258
#
#
# Test accuracy: 78 %
# Epoch:  970   Loss:  429.9287028312683   Train Accuracy : 74.104
#
#
# Test accuracy: 78 %
# Epoch:  971   Loss:  428.2215043902397   Train Accuracy : 74.274
#
#
# Test accuracy: 78 %
# Epoch:  972   Loss:  427.3394280076027   Train Accuracy : 74.456
#
#
# Test accuracy: 78 %
# Epoch:  973   Loss:  429.92910808324814   Train Accuracy : 74.102
#
#
# Test accuracy: 78 %
# Epoch:  974   Loss:  427.0234522819519   Train Accuracy : 74.398
#
#
# Test accuracy: 78 %
# Epoch:  975   Loss:  427.020633995533   Train Accuracy : 74.368
#
#
# Test accuracy: 78 %
# Epoch:  976   Loss:  432.11231607198715   Train Accuracy : 73.992
#
#
# Test accuracy: 78 %
# Epoch:  977   Loss:  429.05875796079636   Train Accuracy : 74.34
#
#
# Test accuracy: 78 %
# Epoch:  978   Loss:  428.61543369293213   Train Accuracy : 74.322
#
#
# Test accuracy: 78 %
# Epoch:  979   Loss:  428.9227470755577   Train Accuracy : 74.456
#
#
# Test accuracy: 78 %
# Epoch:  980   Loss:  430.6142199039459   Train Accuracy : 74.128
#
#
# Test accuracy: 78 %
# Epoch:  981   Loss:  430.6171285510063   Train Accuracy : 73.934
#
#
# Test accuracy: 78 %
# Epoch:  982   Loss:  431.6381709575653   Train Accuracy : 73.994
#
#
# Test accuracy: 78 %
# Epoch:  983   Loss:  427.47532719373703   Train Accuracy : 74.368
#
#
# Test accuracy: 78 %
# Epoch:  984   Loss:  428.15472972393036   Train Accuracy : 74.142
#
#
# Test accuracy: 78 %
# Epoch:  985   Loss:  429.555845618248   Train Accuracy : 74.134
#
#
# Test accuracy: 78 %
# Epoch:  986   Loss:  428.8427887558937   Train Accuracy : 74.042
#
#
# Test accuracy: 78 %
# Epoch:  987   Loss:  428.7749456167221   Train Accuracy : 74.322
#
#
# Test accuracy: 78 %
# Epoch:  988   Loss:  429.9293138384819   Train Accuracy : 74.028
#
#
# Test accuracy: 78 %
# Epoch:  989   Loss:  427.6033828854561   Train Accuracy : 74.202
#
#
# Test accuracy: 78 %
# Epoch:  990   Loss:  431.039319396019   Train Accuracy : 74.28
#
#
# Test accuracy: 78 %
# Epoch:  991   Loss:  428.05276840925217   Train Accuracy : 74.104
#
#
# Test accuracy: 78 %
# Epoch:  992   Loss:  426.6845728754997   Train Accuracy : 74.372
#
#
# Test accuracy: 78 %
# Epoch:  993   Loss:  426.2461937069893   Train Accuracy : 74.534
#
#
# Test accuracy: 78 %
# Epoch:  994   Loss:  432.09408044815063   Train Accuracy : 73.992
#
#
# Test accuracy: 78 %
# Epoch:  995   Loss:  429.44850969314575   Train Accuracy : 74.424
#
#
# Test accuracy: 78 %
# Epoch:  996   Loss:  429.7963876128197   Train Accuracy : 74.084
#
#
# Test accuracy: 78 %
# Epoch:  997   Loss:  426.3594030737877   Train Accuracy : 74.332
#
#
# Test accuracy: 78 %
# Epoch:  998   Loss:  430.6754885315895   Train Accuracy : 74.024
#
#
# Test accuracy: 78 %
# Epoch:  999   Loss:  428.09269791841507   Train Accuracy : 74.158
#
#
# Test accuracy: 78 %
# Epoch:  1000   Loss:  427.4389914870262   Train Accuracy : 74.212
#
#
# Test accuracy: 78 %

# %%
#after training
for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
        imgplot = plt.imshow(m.threshold1.cpu().detach().numpy()[0,1,:] - memorized.cpu().detach().numpy()[0,1,:])
        plt.colorbar()

# %%
#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 78 %
# 78.35
# Accuracy of plane : 90 %
# Accuracy of   car : 84 %
# Accuracy of  bird : 63 %
# Accuracy of   cat : 55 %
# Accuracy of  deer : 71 %
# Accuracy of   dog : 68 %
# Accuracy of  frog : 90 %
# Accuracy of horse : 87 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 89 %

# %%
#Plot the new learned distribution

for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
        
        thresh_hist = torch.histc(m.threshold1)
        start = np.min(m.threshold1.cpu().detach().numpy())
        end = np.max(m.threshold1.cpu().detach().numpy())
        xhist = torch.linspace(start,end,100) # histogram x-axis
        plt.plot(xhist, thresh_hist.cpu().detach().numpy())
        plt.title('Threshold tensor histogram after training')
        plt.ylabel('Count')
        plt.xlabel('Threshold layer values')

# %%
#Plot after training threshold distributions

for idx, m in enumerate(model.block1.modules()):
    if idx == 4:
            
        fig2 = plt.figure()
        plt.figure(figsize=(15,15))
        plt.suptitle('Threshold tensor filter distributions after training', fontsize = 16)
        for idx2, filt  in enumerate(m.threshold1[0,:,:,:]):
            thresh_hist = torch.histc(filt)
            plt.subplot(8,8, idx2 + 1)
            plt.plot(xhist, thresh_hist.cpu().detach().numpy())
