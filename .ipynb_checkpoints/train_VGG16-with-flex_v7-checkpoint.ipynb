# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

from models.VGG16_with_flex_v5 import *


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
#  deer  ship  bird   dog

# %%
# =============================================================== Model initialisation, Loss function and Optimizer =====================================
model = VGG16()
if torch.cuda.is_available():
  model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma = 0.7)

# ======================== Function to get the test accuracy ===============================================================================
def test():
  correct = 0
  total = 0
  model.train(False)
  with torch.no_grad():
    for i,(images,labels)in enumerate(testloader):
      if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
      outputs = model(Variable(images))
      labels = Variable(labels)
      _,predicted = outputs.max(1)
      total += labels.size(0)
      correct += (predicted.eq(labels)).sum().item()
    print('Test accuracy: %d %%' % (
  100 * correct / total))
  return 100*(correct/total)

#======================================================= Training =========================================================================
num_epochs = 200  # Train for 150 epochs
start_epoch = 0

total_step = len(trainloader)
train_loss = []  # Store the train_loss per epoch
test_accuracy = [] # Store the test_accuracy per epoch
for epoch in range(start_epoch,num_epochs+1):
  model.train(True)
  epoch_loss  = 0
  i_count = 0
  acc_total = 0
  for i,(images,labels) in enumerate(trainloader):
    if torch.cuda.is_available():
      images = images.cuda()
      labels = labels.cuda()
    labels = Variable(labels)
    optimizer.zero_grad()
    outputs = model(Variable(images))
    loss = criterion(outputs,labels)
    epoch_loss += loss.item()
    loss.backward()
    optimizer.step()
    _,predicted = outputs.max(1)
    denom = labels.size(0)
    correct = predicted.eq(labels).sum().item()
    acc = 100*(correct/denom)
    acc_total += acc
    i_count = i_count + 1
    
    #if(i%20 == 0):  # Print the loss per 20 iterations
      #print("Epoch: ",epoch," ","Iteration: ",i," loss: ",loss.item()," Train_iter Accuracy: ",acc)
  schedule.step()
  train_loss.append(epoch_loss)
  print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
  print('\n')
  test_acc = test()      # Print the test accuracy per epoch
  test_accuracy.append(test_acc)
  
  if(epoch%50 == 0):       # Save the model every 50 epoch
    state = {
        'model': model.state_dict(),
        'acc' : test_acc,
        'optim':optimizer.state_dict(),
        'epoch' : epoch
    }
    path = './models/VGG16-flex-v5-block1-' + 'model_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
    torch.save(state,path)
# Out:
# Epoch:  0   Loss:  1089.0974884033203   Train Accuracy : 16.65
#
#
# Test accuracy: 18 %
# Epoch:  1   Loss:  963.7847889661789   Train Accuracy : 25.812
#
#
# Test accuracy: 28 %
# Epoch:  2   Loss:  885.566447019577   Train Accuracy : 32.834
#
#
# Test accuracy: 37 %
# Epoch:  3   Loss:  835.4970794916153   Train Accuracy : 37.518
#
#
# Test accuracy: 44 %
# Epoch:  4   Loss:  799.4794623851776   Train Accuracy : 41.572
#
#
# Test accuracy: 49 %
# Epoch:  5   Loss:  760.7045971155167   Train Accuracy : 45.402
#
#
# Test accuracy: 52 %
# Epoch:  6   Loss:  724.1019878387451   Train Accuracy : 49.16
#
#
# Test accuracy: 55 %
# Epoch:  7   Loss:  690.7445820569992   Train Accuracy : 52.38
#
#
# Test accuracy: 59 %
# Epoch:  8   Loss:  662.5089614391327   Train Accuracy : 54.826
#
#
# Test accuracy: 62 %
# Epoch:  9   Loss:  632.5864006280899   Train Accuracy : 57.242
#
#
# Test accuracy: 63 %
# Epoch:  10   Loss:  608.0616831183434   Train Accuracy : 59.654
#
#
# Test accuracy: 65 %
# Epoch:  11   Loss:  586.1224183440208   Train Accuracy : 61.25
#
#
# Test accuracy: 68 %
# Epoch:  12   Loss:  567.3513021469116   Train Accuracy : 62.994
#
#
# Test accuracy: 69 %
# Epoch:  13   Loss:  547.9401572346687   Train Accuracy : 64.316
#
#
# Test accuracy: 66 %
# Epoch:  14   Loss:  528.6601383686066   Train Accuracy : 66.164
#
#
# Test accuracy: 72 %
# Epoch:  15   Loss:  509.3299674987793   Train Accuracy : 67.484
#
#
# Test accuracy: 73 %
# Epoch:  16   Loss:  494.1900525689125   Train Accuracy : 69.022
#
#
# Test accuracy: 73 %
# Epoch:  17   Loss:  476.54767656326294   Train Accuracy : 70.334
#
#
# Test accuracy: 75 %
# Epoch:  18   Loss:  462.430991768837   Train Accuracy : 71.33
#
#
# Test accuracy: 77 %
# Epoch:  19   Loss:  448.3287324309349   Train Accuracy : 72.766
#
#
# Test accuracy: 78 %
# Epoch:  20   Loss:  420.40221667289734   Train Accuracy : 74.844
#
#
# Test accuracy: 78 %
# Epoch:  21   Loss:  410.76802825927734   Train Accuracy : 75.926
#
#
# Test accuracy: 80 %
# Epoch:  22   Loss:  400.07294553518295   Train Accuracy : 76.304
#
#
# Test accuracy: 80 %
# Epoch:  23   Loss:  392.22773987054825   Train Accuracy : 77.192
#
#
# Test accuracy: 80 %
# Epoch:  24   Loss:  383.43128710985184   Train Accuracy : 77.582
#
#
# Test accuracy: 80 %
# Epoch:  25   Loss:  374.5286635160446   Train Accuracy : 78.374
#
#
# Test accuracy: 81 %
# Epoch:  26   Loss:  367.3597680926323   Train Accuracy : 78.884
#
#
# Test accuracy: 81 %
# Epoch:  27   Loss:  360.4236710071564   Train Accuracy : 79.31
#
#
# Test accuracy: 82 %
# Epoch:  28   Loss:  353.6076831817627   Train Accuracy : 79.876
#
#
# Test accuracy: 83 %
# Epoch:  29   Loss:  348.61978816986084   Train Accuracy : 80.408
#
#
# Test accuracy: 83 %
# Epoch:  30   Loss:  342.54607886075974   Train Accuracy : 80.76
#
#
# Test accuracy: 83 %
# Epoch:  31   Loss:  334.59899938106537   Train Accuracy : 81.172
#
#
# Test accuracy: 83 %
# Epoch:  32   Loss:  331.38670936226845   Train Accuracy : 81.576
#
#
# Test accuracy: 84 %
# Epoch:  33   Loss:  320.66876396536827   Train Accuracy : 82.37
#
#
# Test accuracy: 84 %
# Epoch:  34   Loss:  316.93200317025185   Train Accuracy : 82.556
#
#
# Test accuracy: 84 %
# Epoch:  35   Loss:  309.9564488828182   Train Accuracy : 83.084
#
#
# Test accuracy: 85 %
# Epoch:  36   Loss:  306.38668060302734   Train Accuracy : 83.276
#
#
# Test accuracy: 85 %
# Epoch:  37   Loss:  305.1291690468788   Train Accuracy : 83.374
#
#
# Test accuracy: 85 %
# Epoch:  38   Loss:  299.64550548791885   Train Accuracy : 83.82
#
#
# Test accuracy: 85 %
# Epoch:  39   Loss:  291.85147631168365   Train Accuracy : 84.358
#
#
# Test accuracy: 84 %
# Epoch:  40   Loss:  272.4064958691597   Train Accuracy : 85.696
#
#
# Test accuracy: 86 %
# Epoch:  41   Loss:  263.06636145710945   Train Accuracy : 86.282
#
#
# Test accuracy: 86 %
# Epoch:  42   Loss:  258.6550463438034   Train Accuracy : 86.61
#
#
# Test accuracy: 86 %
# Epoch:  43   Loss:  253.0025072991848   Train Accuracy : 87.06
#
#
# Test accuracy: 87 %
# Epoch:  44   Loss:  249.33087047934532   Train Accuracy : 87.162
#
#
# Test accuracy: 86 %
# Epoch:  45   Loss:  244.18701899051666   Train Accuracy : 87.59
#
#
# Test accuracy: 87 %
# Epoch:  46   Loss:  243.6668125987053   Train Accuracy : 87.582
#
#
# Test accuracy: 87 %
# Epoch:  47   Loss:  239.12356692552567   Train Accuracy : 87.75
#
#
# Test accuracy: 87 %
# Epoch:  48   Loss:  237.99116200208664   Train Accuracy : 87.818
#
#
# Test accuracy: 86 %
# Epoch:  49   Loss:  235.06626623868942   Train Accuracy : 88.14
#
#
# Test accuracy: 87 %
# Epoch:  50   Loss:  229.82351638376713   Train Accuracy : 88.346
#
#
# Test accuracy: 87 %
# Epoch:  51   Loss:  231.1318045258522   Train Accuracy : 88.27
#
#
# Test accuracy: 87 %
# Epoch:  52   Loss:  228.17347261309624   Train Accuracy : 88.53
#
#
# Test accuracy: 87 %
# Epoch:  53   Loss:  225.2987912595272   Train Accuracy : 88.596
#
#
# Test accuracy: 87 %
# Epoch:  54   Loss:  221.17473044991493   Train Accuracy : 88.888
#
#
# Test accuracy: 87 %
# Epoch:  55   Loss:  219.5944970101118   Train Accuracy : 88.934
#
#
# Test accuracy: 87 %
# Epoch:  56   Loss:  220.3364298939705   Train Accuracy : 89.006
#
#
# Test accuracy: 87 %
# Epoch:  57   Loss:  214.60847279429436   Train Accuracy : 89.256
#
#
# Test accuracy: 86 %
# Epoch:  58   Loss:  211.6220638602972   Train Accuracy : 89.478
#
#
# Test accuracy: 88 %
# Epoch:  59   Loss:  211.31128641963005   Train Accuracy : 89.62
#
#
# Test accuracy: 88 %
# Epoch:  60   Loss:  191.94638161361217   Train Accuracy : 90.84
#
#
# Test accuracy: 88 %
# Epoch:  61   Loss:  184.5683908611536   Train Accuracy : 91.494
#
#
# Test accuracy: 88 %
# Epoch:  62   Loss:  179.2189120054245   Train Accuracy : 91.8
#
#
# Test accuracy: 88 %
# Epoch:  63   Loss:  172.2915124297142   Train Accuracy : 92.17
#
#
# Test accuracy: 88 %
# Epoch:  64   Loss:  171.14428815245628   Train Accuracy : 92.188
#
#
# Test accuracy: 89 %
# Epoch:  65   Loss:  168.92959886789322   Train Accuracy : 92.444
#
#
# Test accuracy: 89 %
# Epoch:  66   Loss:  168.38373605906963   Train Accuracy : 92.466
#
#
# Test accuracy: 88 %
# Epoch:  67   Loss:  170.3688017129898   Train Accuracy : 92.268
#
#
# Test accuracy: 89 %
# Epoch:  68   Loss:  167.01670671999454   Train Accuracy : 92.466
#
#
# Test accuracy: 88 %
# Epoch:  69   Loss:  166.14089487493038   Train Accuracy : 92.49
#
#
# Test accuracy: 89 %
# Epoch:  70   Loss:  162.1860584616661   Train Accuracy : 92.752
#
#
# Test accuracy: 88 %
# Epoch:  71   Loss:  165.80900764465332   Train Accuracy : 92.646
#
#
# Test accuracy: 88 %
# Epoch:  72   Loss:  161.12231281399727   Train Accuracy : 92.75
#
#
# Test accuracy: 88 %
# Epoch:  73   Loss:  157.20599661767483   Train Accuracy : 92.964
#
#
# Test accuracy: 88 %
# Epoch:  74   Loss:  160.8607231527567   Train Accuracy : 92.76
#
#
# Test accuracy: 88 %
# Epoch:  75   Loss:  156.05712509155273   Train Accuracy : 93.134
#
#
# Test accuracy: 88 %
# Epoch:  76   Loss:  154.29308496415615   Train Accuracy : 93.11
#
#
# Test accuracy: 89 %
# Epoch:  77   Loss:  153.06250455975533   Train Accuracy : 93.216
#
#
# Test accuracy: 88 %
# Epoch:  78   Loss:  154.8638002872467   Train Accuracy : 93.276
#
#
# Test accuracy: 89 %
# Epoch:  79   Loss:  151.26849648356438   Train Accuracy : 93.43
#
#
# Test accuracy: 89 %
# Epoch:  80   Loss:  136.10284393280745   Train Accuracy : 94.44
#
#
# Test accuracy: 89 %
# Epoch:  81   Loss:  128.94588052481413   Train Accuracy : 94.892
#
#
# Test accuracy: 89 %
# Epoch:  82   Loss:  127.73536297678947   Train Accuracy : 95.054
#
#
# Test accuracy: 89 %
# Epoch:  83   Loss:  126.75085088610649   Train Accuracy : 95.06
#
#
# Test accuracy: 88 %
# Epoch:  84   Loss:  124.52976922690868   Train Accuracy : 95.054
#
#
# Test accuracy: 89 %
# Epoch:  85   Loss:  122.3458744585514   Train Accuracy : 95.284
#
#
# Test accuracy: 89 %
# Epoch:  86   Loss:  119.02538822591305   Train Accuracy : 95.566
#
#
# Test accuracy: 89 %
# Epoch:  87   Loss:  119.27575960755348   Train Accuracy : 95.32
#
#
# Test accuracy: 88 %
# Epoch:  88   Loss:  118.80188082158566   Train Accuracy : 95.486
#
#
# Test accuracy: 89 %
# Epoch:  89   Loss:  119.07480732351542   Train Accuracy : 95.476
#
#
# Test accuracy: 89 %
# Epoch:  90   Loss:  115.15702895820141   Train Accuracy : 95.74
#
#
# Test accuracy: 89 %
# Epoch:  91   Loss:  114.1830587387085   Train Accuracy : 95.758
#
#
# Test accuracy: 89 %
# Epoch:  92   Loss:  111.05418498814106   Train Accuracy : 95.956
#
#
# Test accuracy: 89 %
# Epoch:  93   Loss:  115.77817137539387   Train Accuracy : 95.65
#
#
# Test accuracy: 89 %
# Epoch:  94   Loss:  113.15595441311598   Train Accuracy : 95.728
#
#
# Test accuracy: 89 %
# Epoch:  95   Loss:  114.34270094335079   Train Accuracy : 95.714
#
#
# Test accuracy: 89 %
# Epoch:  96   Loss:  109.92759618163109   Train Accuracy : 95.934
#
#
# Test accuracy: 89 %
# Epoch:  97   Loss:  110.7421844676137   Train Accuracy : 95.886
#
#
# Test accuracy: 89 %
# Epoch:  98   Loss:  112.69809219241142   Train Accuracy : 95.764
#
#
# Test accuracy: 89 %
# Epoch:  99   Loss:  112.8398358374834   Train Accuracy : 95.736
#
#
# Test accuracy: 89 %
# Epoch:  100   Loss:  102.85878589004278   Train Accuracy : 96.396
#
#
# Test accuracy: 90 %
# Epoch:  101   Loss:  95.84536498039961   Train Accuracy : 96.904
#
#
# Test accuracy: 89 %
# Epoch:  102   Loss:  92.54177711158991   Train Accuracy : 97.064
#
#
# Test accuracy: 90 %
# Epoch:  103   Loss:  92.98437000066042   Train Accuracy : 97.028
#
#
# Test accuracy: 89 %
# Epoch:  104   Loss:  88.80302499234676   Train Accuracy : 97.254
#
#
# Test accuracy: 89 %
# Epoch:  105   Loss:  90.2456149533391   Train Accuracy : 97.106
#
#
# Test accuracy: 89 %
# Epoch:  106   Loss:  88.93297949433327   Train Accuracy : 97.266
#
#
# Test accuracy: 89 %
# Epoch:  107   Loss:  88.37990683317184   Train Accuracy : 97.358
#
#
# Test accuracy: 90 %
# Epoch:  108   Loss:  86.81394897401333   Train Accuracy : 97.416
#
#
# Test accuracy: 89 %
# Epoch:  109   Loss:  85.53224541246891   Train Accuracy : 97.406
#
#
# Test accuracy: 89 %
# Epoch:  110   Loss:  86.25508456677198   Train Accuracy : 97.434
#
#
# Test accuracy: 89 %
# Epoch:  111   Loss:  85.39305754750967   Train Accuracy : 97.498
#
#
# Test accuracy: 89 %
# Epoch:  112   Loss:  83.1312674805522   Train Accuracy : 97.59
#
#
# Test accuracy: 89 %
# Epoch:  113   Loss:  84.37238404154778   Train Accuracy : 97.566
#
#
# Test accuracy: 89 %
# Epoch:  114   Loss:  85.8120204731822   Train Accuracy : 97.396
#
#
# Test accuracy: 89 %
# Epoch:  115   Loss:  81.91524425148964   Train Accuracy : 97.658
#
#
# Test accuracy: 90 %
# Epoch:  116   Loss:  83.13368984311819   Train Accuracy : 97.582
#
#
# Test accuracy: 89 %
# Epoch:  117   Loss:  83.43511188775301   Train Accuracy : 97.596
#
#
# Test accuracy: 89 %
# Epoch:  118   Loss:  85.1200503706932   Train Accuracy : 97.466
#
#
# Test accuracy: 89 %
# Epoch:  119   Loss:  85.38376209884882   Train Accuracy : 97.394
#
#
# Test accuracy: 90 %
# Epoch:  120   Loss:  79.20100966095924   Train Accuracy : 97.788
#
#
# Test accuracy: 90 %
# Epoch:  121   Loss:  74.97725258022547   Train Accuracy : 98.062
#
#
# Test accuracy: 89 %
# Epoch:  122   Loss:  73.57088404893875   Train Accuracy : 98.092
#
#
# Test accuracy: 90 %
# Epoch:  123   Loss:  72.53768717497587   Train Accuracy : 98.198
#
#
# Test accuracy: 90 %
# Epoch:  124   Loss:  71.02547677606344   Train Accuracy : 98.284
#
#
# Test accuracy: 89 %
# Epoch:  125   Loss:  70.23288232833147   Train Accuracy : 98.314
#
#
# Test accuracy: 89 %
# Epoch:  126   Loss:  71.46552160382271   Train Accuracy : 98.23
#
#
# Test accuracy: 90 %
# Epoch:  127   Loss:  71.02016232907772   Train Accuracy : 98.284
#
#
# Test accuracy: 90 %
# Epoch:  128   Loss:  68.89803196489811   Train Accuracy : 98.388
#
#
# Test accuracy: 90 %
# Epoch:  129   Loss:  67.448465898633   Train Accuracy : 98.504
#
#
# Test accuracy: 89 %
# Epoch:  130   Loss:  69.07463233172894   Train Accuracy : 98.5
#
#
# Test accuracy: 90 %
# Epoch:  131   Loss:  66.59322553128004   Train Accuracy : 98.486
#
#
# Test accuracy: 90 %
# Epoch:  132   Loss:  66.59912499785423   Train Accuracy : 98.534
#
#
# Test accuracy: 90 %
# Epoch:  133   Loss:  67.82473807036877   Train Accuracy : 98.482
#
#
# Test accuracy: 90 %
# Epoch:  134   Loss:  67.62064092978835   Train Accuracy : 98.454
#
#
# Test accuracy: 89 %
# Epoch:  135   Loss:  66.41665475815535   Train Accuracy : 98.544
#
#
# Test accuracy: 89 %
# Epoch:  136   Loss:  67.2047230899334   Train Accuracy : 98.49
#
#
# Test accuracy: 89 %
# Epoch:  137   Loss:  67.13574208319187   Train Accuracy : 98.476
#
#
# Test accuracy: 89 %
# Epoch:  138   Loss:  66.37674816697836   Train Accuracy : 98.532
#
#
# Test accuracy: 90 %
# Epoch:  139   Loss:  67.61986519396305   Train Accuracy : 98.468
#
#
# Test accuracy: 89 %
# Epoch:  140   Loss:  64.16272399574518   Train Accuracy : 98.678
#
#
# Test accuracy: 90 %
# Epoch:  141   Loss:  63.370268791913986   Train Accuracy : 98.768
#
#
# Test accuracy: 90 %
# Epoch:  142   Loss:  62.24854737892747   Train Accuracy : 98.804
#
#
# Test accuracy: 90 %
# Epoch:  143   Loss:  61.73915456235409   Train Accuracy : 98.844
#
#
# Test accuracy: 90 %
# Epoch:  144   Loss:  60.77996291965246   Train Accuracy : 98.86
#
#
# Test accuracy: 90 %
# Epoch:  145   Loss:  60.74752455949783   Train Accuracy : 98.904
#
#
# Test accuracy: 90 %
# Epoch:  146   Loss:  59.62337835878134   Train Accuracy : 98.952
#
#
# Test accuracy: 90 %
# Epoch:  147   Loss:  60.67223935946822   Train Accuracy : 98.888
#
#
# Test accuracy: 90 %
# Epoch:  148   Loss:  59.99022187292576   Train Accuracy : 98.866
#
#
# Test accuracy: 90 %
# Epoch:  149   Loss:  59.3621089681983   Train Accuracy : 98.934
#
#
# Test accuracy: 90 %
# Epoch:  150   Loss:  60.10973187536001   Train Accuracy : 98.932
#
#
# Test accuracy: 90 %
# Epoch:  151   Loss:  60.006040677428246   Train Accuracy : 98.95
#
#
# Test accuracy: 90 %
# Epoch:  152   Loss:  58.236064322292805   Train Accuracy : 99.08
#
#
# Test accuracy: 90 %
# Epoch:  153   Loss:  59.582282315939665   Train Accuracy : 98.912
#
#
# Test accuracy: 90 %
# Epoch:  154   Loss:  58.255921840667725   Train Accuracy : 98.95
#
#
# Test accuracy: 89 %
# Epoch:  155   Loss:  58.987067215144634   Train Accuracy : 99.004
#
#
# Test accuracy: 90 %
# Epoch:  156   Loss:  58.12775009870529   Train Accuracy : 99.054
#
#
# Test accuracy: 90 %
# Epoch:  157   Loss:  59.248840786516666   Train Accuracy : 98.956
#
#
# Test accuracy: 90 %
# Epoch:  158   Loss:  58.06539995968342   Train Accuracy : 98.972
#
#
# Test accuracy: 90 %
# Epoch:  159   Loss:  58.377160128206015   Train Accuracy : 98.97
#
#
# Test accuracy: 90 %
# Epoch:  160   Loss:  56.7036127820611   Train Accuracy : 99.058
#
#
# Test accuracy: 90 %
# Epoch:  161   Loss:  56.89548724889755   Train Accuracy : 99.076
#
#
# Test accuracy: 90 %
# Epoch:  162   Loss:  56.258173901587725   Train Accuracy : 99.096
#
#
# Test accuracy: 90 %
# Epoch:  163   Loss:  57.303735338151455   Train Accuracy : 99.05
#
#
# Test accuracy: 90 %
# Epoch:  164   Loss:  57.09615372121334   Train Accuracy : 99.106
#
#
# Test accuracy: 90 %
# Epoch:  165   Loss:  56.03105792030692   Train Accuracy : 99.146
#
#
# Test accuracy: 90 %
# Epoch:  166   Loss:  55.608720541000366   Train Accuracy : 99.082
#
#
# Test accuracy: 90 %
# Epoch:  167   Loss:  55.01177836954594   Train Accuracy : 99.132
#
#
# Test accuracy: 90 %
# Epoch:  168   Loss:  55.48774549737573   Train Accuracy : 99.164
#
#
# Test accuracy: 90 %
# Epoch:  169   Loss:  54.17042601853609   Train Accuracy : 99.218
#
#
# Test accuracy: 90 %
# Epoch:  170   Loss:  54.600534968078136   Train Accuracy : 99.158
#
#
# Test accuracy: 90 %
# Epoch:  171   Loss:  54.52250253409147   Train Accuracy : 99.198
#
#
# Test accuracy: 90 %
# Epoch:  172   Loss:  55.39193169027567   Train Accuracy : 99.142
#
#
# Test accuracy: 90 %
# Epoch:  173   Loss:  54.33564855158329   Train Accuracy : 99.162
#
#
# Test accuracy: 90 %
# Epoch:  174   Loss:  54.535833805799484   Train Accuracy : 99.268
#
#
# Test accuracy: 90 %
# Epoch:  175   Loss:  55.01799086481333   Train Accuracy : 99.222
#
#
# Test accuracy: 90 %
# Epoch:  176   Loss:  54.25352165848017   Train Accuracy : 99.23
#
#
# Test accuracy: 90 %
# Epoch:  177   Loss:  54.5444216504693   Train Accuracy : 99.188
#
#
# Test accuracy: 90 %
# Epoch:  178   Loss:  55.266367487609386   Train Accuracy : 99.142
#
#
# Test accuracy: 90 %
# Epoch:  179   Loss:  54.04583667963743   Train Accuracy : 99.194
#
#
# Test accuracy: 90 %
# Epoch:  180   Loss:  54.29183594882488   Train Accuracy : 99.224
#
#
# Test accuracy: 90 %
# Epoch:  181   Loss:  53.72860599681735   Train Accuracy : 99.334
#
#
# Test accuracy: 90 %
# Epoch:  182   Loss:  53.04419996216893   Train Accuracy : 99.236
#
#
# Test accuracy: 90 %
# Epoch:  183   Loss:  53.86893867701292   Train Accuracy : 99.282
#
#
# Test accuracy: 90 %
# Epoch:  184   Loss:  53.419154323637486   Train Accuracy : 99.292
#
#
# Test accuracy: 90 %
# Epoch:  185   Loss:  53.102469593286514   Train Accuracy : 99.268
#
#
# Test accuracy: 90 %
# Epoch:  186   Loss:  53.12137287482619   Train Accuracy : 99.254
#
#
# Test accuracy: 90 %
# Epoch:  187   Loss:  53.48475777357817   Train Accuracy : 99.272
#
#
# Test accuracy: 90 %
# Epoch:  188   Loss:  52.715546902269125   Train Accuracy : 99.3
#
#
# Test accuracy: 90 %
# Epoch:  189   Loss:  52.727423779666424   Train Accuracy : 99.316
#
#
# Test accuracy: 90 %
# Epoch:  190   Loss:  53.10216495767236   Train Accuracy : 99.224
#
#
# Test accuracy: 90 %
# Epoch:  191   Loss:  53.004087783396244   Train Accuracy : 99.26
#
#
# Test accuracy: 90 %
# Epoch:  192   Loss:  52.3409737534821   Train Accuracy : 99.336
#
#
# Test accuracy: 90 %
# Epoch:  193   Loss:  52.102746333926916   Train Accuracy : 99.324
#
#
# Test accuracy: 90 %
# Epoch:  194   Loss:  52.5191463381052   Train Accuracy : 99.302
#
#
# Test accuracy: 90 %
# Epoch:  195   Loss:  52.43304669111967   Train Accuracy : 99.318
#
#
# Test accuracy: 90 %
# Epoch:  196   Loss:  52.77644693478942   Train Accuracy : 99.276
#
#
# Test accuracy: 91 %
# Epoch:  197   Loss:  52.43242874741554   Train Accuracy : 99.31
#
#
# Test accuracy: 90 %
# Epoch:  198   Loss:  52.6934680826962   Train Accuracy : 99.26
#
#
# Test accuracy: 90 %
# Epoch:  199   Loss:  51.92458700761199   Train Accuracy : 99.35
#
#
# Test accuracy: 90 %
# Epoch:  200   Loss:  52.193740639835596   Train Accuracy : 99.35
#
#
# Test accuracy: 90 %

# %%
#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 90 %
# 90.86
# Accuracy of plane : 93 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 81 %
# Accuracy of   cat : 74 %
# Accuracy of  deer : 93 %
# Accuracy of   dog : 84 %
# Accuracy of  frog : 94 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 95 %
# Accuracy of truck : 100 %
