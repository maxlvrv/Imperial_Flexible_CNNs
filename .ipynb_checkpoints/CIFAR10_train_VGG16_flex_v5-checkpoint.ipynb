# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# ================================================= Flexible Layer ================================================================================

    
class FlexiLayer(nn.Module): # class FlexiLayer(nn.Conv2d):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 padding=0):
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        super(FlexiLayer, self).__init__()
        
        self.t_1 = nn.Conv2d(self.in_channels, self.out_channels, self.kernel_size, self.stride, self.padding)
        self.t_2 = nn.MaxPool2d(self.kernel_size, self.stride, self.padding) # get max result with the same kernel size
        self.m = nn.Sigmoid()
        
        self.threshold1 = Variable(torch.randn((1, self.out_channels, 30, 30)))
        
        self.thresh_mean = []
        
    def forward(self, t):
        
        self.threshold1.expand(t.size(0), self.out_channels, 30, 30)
        
        
        cond = torch.sub(self.t_2(t), self.threshold1.cuda())
        t_2_2 = self.m(cond*50)*self.t_2(t) # 
        t_1_1 = self.m(cond*(-50))*self.t_1(t) # 
        t = torch.add(t_2_2, t_1_1)
        
        return t

    # ================================================= VGG-16 Network ================================================================================
class VGG16(nn.Module):
  def __init__(self):
    super(VGG16,self).__init__()

    self.block1 = nn.Sequential(
                  nn.Conv2d(in_channels = 3,out_channels = 64,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(64),
                  nn.ReLU(),
                  FlexiLayer(in_channels = 64,out_channels = 64,kernel_size = 3, padding =0),
                  nn.BatchNorm2d(64),
                  nn.ReLU(),
                  #nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.3))

    self.block2 = nn.Sequential(
                  nn.Conv2d(in_channels = 64,out_channels = 128,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(128),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 128,out_channels = 128,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(128),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.4))

    self.block3 = nn.Sequential(
                  nn.Conv2d(in_channels = 128,out_channels = 256,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(256),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(256),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(256),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.4))

    self.block4 = nn.Sequential(
                  nn.Conv2d(in_channels = 256,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2) ,
                  nn.Dropout2d(0.4))

    self.block5 = nn.Sequential(
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.5) )

    self.fc =     nn.Sequential(
                  nn.Linear(512,100),
                  nn.Dropout(0.5),
                  nn.BatchNorm1d(100),
                  nn.ReLU(),
                  nn.Dropout(0.5),
                  nn.Linear(100,10), )
                  
                  


  def forward(self,x):
    out = self.block1(x)
    out = self.block2(out)
    out = self.block3(out)
    out = self.block4(out)
    out = self.block5(out)
    out = out.view(out.size(0),-1)
    out = self.fc(out)

    return out

# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

#from models.VGG16_with_flex_v5 import *


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
# plane truck  frog plane

# %%
# =============================================================== Model initialisation, Loss function and Optimizer =====================================
model = VGG16()
if torch.cuda.is_available():
  model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma = 0.7)

total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} trainable parameters.')
# Out:
# 14,775,646 total parameters.
# 14,775,646 trainable parameters.

# %%
# ======================== Function to get the test accuracy ===============================================================================
def test():
  correct = 0
  total = 0
  model.train(False)
  with torch.no_grad():
    for i,(images,labels)in enumerate(testloader):
      if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
      outputs = model(Variable(images))
      labels = Variable(labels)
      _,predicted = outputs.max(1)
      total += labels.size(0)
      correct += (predicted.eq(labels)).sum().item()
    print('Test accuracy: %d %%' % (
  100 * correct / total))
  return 100*(correct/total)

#======================================================= Training =========================================================================
num_epochs = 152  # Train for 150 epochs
start_epoch = 0

total_step = len(trainloader)
train_loss = []  # Store the train_loss per epoch
test_accuracy = [] # Store the test_accuracy per epoch
for epoch in range(start_epoch,num_epochs+1):
  model.train(True)
  epoch_loss  = 0
  i_count = 0
  acc_total = 0
  for i,(images,labels) in enumerate(trainloader):
    if torch.cuda.is_available():
      images = images.cuda()
      labels = labels.cuda()
    labels = Variable(labels)
    optimizer.zero_grad()
    outputs = model(Variable(images))
    loss = criterion(outputs,labels)
    epoch_loss += loss.item()
    loss.backward()
    optimizer.step()
    _,predicted = outputs.max(1)
    denom = labels.size(0)
    correct = predicted.eq(labels).sum().item()
    acc = 100*(correct/denom)
    acc_total += acc
    i_count = i_count + 1
    
    #if(i%20 == 0):  # Print the loss per 20 iterations
      #print("Epoch: ",epoch," ","Iteration: ",i," loss: ",loss.item()," Train_iter Accuracy: ",acc)
  schedule.step()
  train_loss.append(epoch_loss)
  print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
  print('\n')
  test_acc = test()      # Print the test accuracy per epoch
  test_accuracy.append(test_acc)
  
  if(epoch%50 == 0):       # Save the model every 50 epoch
    state = {
        'model': model.state_dict(),
        'acc' : test_acc,
        'optim':optimizer.state_dict(),
        'epoch' : epoch
    }
    path = './models/VGG16-flex-v5-block1-nnmodule_' + 'model_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
    torch.save(state,path)
# Out:
# Epoch:  0   Loss:  1081.269240140915   Train Accuracy : 17.906
#
#
# Test accuracy: 18 %
# Epoch:  1   Loss:  948.0896731615067   Train Accuracy : 27.52
#
#
# Test accuracy: 31 %
# Epoch:  2   Loss:  877.9890699386597   Train Accuracy : 33.342
#
#
# Test accuracy: 39 %
# Epoch:  3   Loss:  833.0976151227951   Train Accuracy : 37.562
#
#
# Test accuracy: 44 %
# Epoch:  4   Loss:  793.4754889011383   Train Accuracy : 41.142
#
#
# Test accuracy: 48 %
# Epoch:  5   Loss:  758.1053202152252   Train Accuracy : 44.956
#
#
# Test accuracy: 51 %
# Epoch:  6   Loss:  725.202531337738   Train Accuracy : 48.458
#
#
# Test accuracy: 56 %
# Epoch:  7   Loss:  694.1728743314743   Train Accuracy : 51.59
#
#
# Test accuracy: 58 %
# Epoch:  8   Loss:  660.0326182842255   Train Accuracy : 54.792
#
#
# Test accuracy: 61 %
# Epoch:  9   Loss:  631.373309969902   Train Accuracy : 57.304
#
#
# Test accuracy: 63 %
# Epoch:  10   Loss:  605.3968154788017   Train Accuracy : 59.532
#
#
# Test accuracy: 65 %
# Epoch:  11   Loss:  581.0349714159966   Train Accuracy : 61.71
#
#
# Test accuracy: 68 %
# Epoch:  12   Loss:  560.7812497615814   Train Accuracy : 63.594
#
#
# Test accuracy: 70 %
# Epoch:  13   Loss:  538.3726063370705   Train Accuracy : 65.184
#
#
# Test accuracy: 70 %
# Epoch:  14   Loss:  518.3639250993729   Train Accuracy : 67.046
#
#
# Test accuracy: 73 %
# Epoch:  15   Loss:  501.4980395436287   Train Accuracy : 68.25
#
#
# Test accuracy: 74 %
# Epoch:  16   Loss:  488.52033668756485   Train Accuracy : 69.54
#
#
# Test accuracy: 74 %
# Epoch:  17   Loss:  470.865214407444   Train Accuracy : 71.19
#
#
# Test accuracy: 77 %
# Epoch:  18   Loss:  459.2426281571388   Train Accuracy : 72.22
#
#
# Test accuracy: 77 %
# Epoch:  19   Loss:  442.45602852106094   Train Accuracy : 73.432
#
#
# Test accuracy: 79 %
# Epoch:  20   Loss:  416.55506122112274   Train Accuracy : 75.672
#
#
# Test accuracy: 79 %
# Epoch:  21   Loss:  401.49348616600037   Train Accuracy : 76.492
#
#
# Test accuracy: 80 %
# Epoch:  22   Loss:  394.56593948602676   Train Accuracy : 77.004
#
#
# Test accuracy: 80 %
# Epoch:  23   Loss:  385.99165892601013   Train Accuracy : 77.61
#
#
# Test accuracy: 81 %
# Epoch:  24   Loss:  376.7342154979706   Train Accuracy : 78.294
#
#
# Test accuracy: 81 %
# Epoch:  25   Loss:  365.30299922823906   Train Accuracy : 78.988
#
#
# Test accuracy: 81 %
# Epoch:  26   Loss:  363.02009186148643   Train Accuracy : 79.384
#
#
# Test accuracy: 81 %
# Epoch:  27   Loss:  353.8693935573101   Train Accuracy : 80.006
#
#
# Test accuracy: 81 %
# Epoch:  28   Loss:  346.3108309805393   Train Accuracy : 80.638
#
#
# Test accuracy: 82 %
# Epoch:  29   Loss:  342.5061505436897   Train Accuracy : 80.734
#
#
# Test accuracy: 83 %
# Epoch:  30   Loss:  335.20785841345787   Train Accuracy : 81.324
#
#
# Test accuracy: 83 %
# Epoch:  31   Loss:  327.6327848434448   Train Accuracy : 81.788
#
#
# Test accuracy: 84 %
# Epoch:  32   Loss:  322.31987193226814   Train Accuracy : 82.006
#
#
# Test accuracy: 84 %
# Epoch:  33   Loss:  317.2777725160122   Train Accuracy : 82.344
#
#
# Test accuracy: 84 %
# Epoch:  34   Loss:  313.19245278835297   Train Accuracy : 82.684
#
#
# Test accuracy: 84 %
# Epoch:  35   Loss:  308.69093933701515   Train Accuracy : 83.198
#
#
# Test accuracy: 84 %
# Epoch:  36   Loss:  300.8273845911026   Train Accuracy : 83.606
#
#
# Test accuracy: 85 %
# Epoch:  37   Loss:  297.35317784547806   Train Accuracy : 83.9
#
#
# Test accuracy: 85 %
# Epoch:  38   Loss:  298.13627579808235   Train Accuracy : 83.846
#
#
# Test accuracy: 85 %
# Epoch:  39   Loss:  290.1741811335087   Train Accuracy : 84.336
#
#
# Test accuracy: 85 %
# Epoch:  40   Loss:  268.76562333106995   Train Accuracy : 85.914
#
#
# Test accuracy: 85 %
# Epoch:  41   Loss:  257.4833698272705   Train Accuracy : 86.544
#
#
# Test accuracy: 86 %
# Epoch:  42   Loss:  253.00110638141632   Train Accuracy : 86.95
#
#
# Test accuracy: 86 %
# Epoch:  43   Loss:  247.4683684706688   Train Accuracy : 87.376
#
#
# Test accuracy: 86 %
# Epoch:  44   Loss:  248.08107641339302   Train Accuracy : 87.288
#
#
# Test accuracy: 86 %
# Epoch:  45   Loss:  243.98756009340286   Train Accuracy : 87.452
#
#
# Test accuracy: 87 %
# Epoch:  46   Loss:  240.0499044060707   Train Accuracy : 87.818
#
#
# Test accuracy: 87 %
# Epoch:  47   Loss:  236.2143335044384   Train Accuracy : 87.856
#
#
# Test accuracy: 87 %
# Epoch:  48   Loss:  233.97883567214012   Train Accuracy : 88.228
#
#
# Test accuracy: 86 %
# Epoch:  49   Loss:  230.80738431215286   Train Accuracy : 88.358
#
#
# Test accuracy: 87 %
# Epoch:  50   Loss:  226.99576660990715   Train Accuracy : 88.642
#
#
# Test accuracy: 87 %
# Epoch:  51   Loss:  228.02837792038918   Train Accuracy : 88.438
#
#
# Test accuracy: 87 %
# Epoch:  52   Loss:  227.19875974953175   Train Accuracy : 88.572
#
#
# Test accuracy: 87 %
# Epoch:  53   Loss:  221.39819231629372   Train Accuracy : 88.978
#
#
# Test accuracy: 87 %
# Epoch:  54   Loss:  217.93171785771847   Train Accuracy : 89.038
#
#
# Test accuracy: 87 %
# Epoch:  55   Loss:  217.7667536586523   Train Accuracy : 89.222
#
#
# Test accuracy: 87 %
# Epoch:  56   Loss:  215.00172090530396   Train Accuracy : 89.334
#
#
# Test accuracy: 87 %
# Epoch:  57   Loss:  211.43150106072426   Train Accuracy : 89.474
#
#
# Test accuracy: 87 %
# Epoch:  58   Loss:  212.97670124471188   Train Accuracy : 89.522
#
#
# Test accuracy: 87 %
# Epoch:  59   Loss:  207.63894847035408   Train Accuracy : 89.784
#
#
# Test accuracy: 87 %
# Epoch:  60   Loss:  189.8842804133892   Train Accuracy : 91.014
#
#
# Test accuracy: 88 %
# Epoch:  61   Loss:  179.9063768684864   Train Accuracy : 91.636
#
#
# Test accuracy: 87 %
# Epoch:  62   Loss:  177.27771845459938   Train Accuracy : 91.794
#
#
# Test accuracy: 88 %
# Epoch:  63   Loss:  171.76128546893597   Train Accuracy : 92.182
#
#
# Test accuracy: 88 %
# Epoch:  64   Loss:  173.7468839585781   Train Accuracy : 92.036
#
#
# Test accuracy: 88 %
# Epoch:  65   Loss:  168.91571646928787   Train Accuracy : 92.308
#
#
# Test accuracy: 88 %
# Epoch:  66   Loss:  166.40592332184315   Train Accuracy : 92.54
#
#
# Test accuracy: 87 %
# Epoch:  67   Loss:  164.33927926421165   Train Accuracy : 92.524
#
#
# Test accuracy: 88 %
# Epoch:  68   Loss:  164.48718012869358   Train Accuracy : 92.546
#
#
# Test accuracy: 88 %
# Epoch:  69   Loss:  161.67178812623024   Train Accuracy : 92.664
#
#
# Test accuracy: 88 %
# Epoch:  70   Loss:  160.43922168016434   Train Accuracy : 92.83
#
#
# Test accuracy: 88 %
# Epoch:  71   Loss:  158.9555568099022   Train Accuracy : 92.858
#
#
# Test accuracy: 88 %
# Epoch:  72   Loss:  159.79648460447788   Train Accuracy : 92.886
#
#
# Test accuracy: 88 %
# Epoch:  73   Loss:  158.38828894495964   Train Accuracy : 92.976
#
#
# Test accuracy: 88 %
# Epoch:  74   Loss:  154.61447271704674   Train Accuracy : 93.2
#
#
# Test accuracy: 88 %
# Epoch:  75   Loss:  156.68198856711388   Train Accuracy : 92.962
#
#
# Test accuracy: 88 %
# Epoch:  76   Loss:  153.65114864706993   Train Accuracy : 93.294
#
#
# Test accuracy: 88 %
# Epoch:  77   Loss:  153.07192592322826   Train Accuracy : 93.26
#
#
# Test accuracy: 88 %
# Epoch:  78   Loss:  151.56193308532238   Train Accuracy : 93.408
#
#
# Test accuracy: 88 %
# Epoch:  79   Loss:  152.23920400440693   Train Accuracy : 93.234
#
#
# Test accuracy: 88 %
# Epoch:  80   Loss:  136.50786596536636   Train Accuracy : 94.384
#
#
# Test accuracy: 89 %
# Epoch:  81   Loss:  132.60780926793814   Train Accuracy : 94.608
#
#
# Test accuracy: 89 %
# Epoch:  82   Loss:  128.55897922813892   Train Accuracy : 94.936
#
#
# Test accuracy: 89 %
# Epoch:  83   Loss:  124.25961098074913   Train Accuracy : 95.27
#
#
# Test accuracy: 89 %
# Epoch:  84   Loss:  119.03733612596989   Train Accuracy : 95.522
#
#
# Test accuracy: 89 %
# Epoch:  85   Loss:  119.94243690371513   Train Accuracy : 95.51
#
#
# Test accuracy: 89 %
# Epoch:  86   Loss:  120.60776577889919   Train Accuracy : 95.278
#
#
# Test accuracy: 89 %
# Epoch:  87   Loss:  114.26128640770912   Train Accuracy : 95.758
#
#
# Test accuracy: 89 %
# Epoch:  88   Loss:  115.24149622768164   Train Accuracy : 95.65
#
#
# Test accuracy: 88 %
# Epoch:  89   Loss:  115.3590262979269   Train Accuracy : 95.572
#
#
# Test accuracy: 88 %
# Epoch:  90   Loss:  116.89193806797266   Train Accuracy : 95.674
#
#
# Test accuracy: 89 %
# Epoch:  91   Loss:  117.14928358793259   Train Accuracy : 95.588
#
#
# Test accuracy: 89 %
# Epoch:  92   Loss:  113.27407747507095   Train Accuracy : 95.816
#
#
# Test accuracy: 88 %
# Epoch:  93   Loss:  114.79714602977037   Train Accuracy : 95.634
#
#
# Test accuracy: 89 %
# Epoch:  94   Loss:  110.01422230899334   Train Accuracy : 96.024
#
#
# Test accuracy: 88 %
# Epoch:  95   Loss:  110.34779755026102   Train Accuracy : 95.964
#
#
# Test accuracy: 89 %
# Epoch:  96   Loss:  109.62942185997963   Train Accuracy : 95.988
#
#
# Test accuracy: 89 %
# Epoch:  97   Loss:  111.96316209435463   Train Accuracy : 95.728
#
#
# Test accuracy: 88 %
# Epoch:  98   Loss:  108.71821297705173   Train Accuracy : 96.06
#
#
# Test accuracy: 88 %
# Epoch:  99   Loss:  110.33434584736824   Train Accuracy : 95.902
#
#
# Test accuracy: 88 %
# Epoch:  100   Loss:  98.84082827717066   Train Accuracy : 96.636
#
#
# Test accuracy: 89 %
# Epoch:  101   Loss:  97.08037970215082   Train Accuracy : 96.724
#
#
# Test accuracy: 89 %
# Epoch:  102   Loss:  93.02959044277668   Train Accuracy : 96.95
#
#
# Test accuracy: 89 %
# Epoch:  103   Loss:  90.9158540442586   Train Accuracy : 97.252
#
#
# Test accuracy: 89 %
# Epoch:  104   Loss:  89.46168142557144   Train Accuracy : 97.254
#
#
# Test accuracy: 89 %
# Epoch:  105   Loss:  89.34154768288136   Train Accuracy : 97.214
#
#
# Test accuracy: 89 %
# Epoch:  106   Loss:  86.43965818732977   Train Accuracy : 97.482
#
#
# Test accuracy: 89 %
# Epoch:  107   Loss:  88.08512692898512   Train Accuracy : 97.278
#
#
# Test accuracy: 89 %
# Epoch:  108   Loss:  84.3765920996666   Train Accuracy : 97.598
#
#
# Test accuracy: 89 %
# Epoch:  109   Loss:  85.48918871581554   Train Accuracy : 97.494
#
#
# Test accuracy: 89 %
# Epoch:  110   Loss:  83.76889376342297   Train Accuracy : 97.564
#
#
# Test accuracy: 89 %
# Epoch:  111   Loss:  83.5554037541151   Train Accuracy : 97.564
#
#
# Test accuracy: 89 %
# Epoch:  112   Loss:  83.6315520554781   Train Accuracy : 97.594
#
#
# Test accuracy: 89 %
# Epoch:  113   Loss:  83.18849869817495   Train Accuracy : 97.586
#
#
# Test accuracy: 89 %
# Epoch:  114   Loss:  85.01381727308035   Train Accuracy : 97.46
#
#
# Test accuracy: 89 %
# Epoch:  115   Loss:  83.87159900739789   Train Accuracy : 97.544
#
#
# Test accuracy: 89 %
# Epoch:  116   Loss:  83.49827130138874   Train Accuracy : 97.564
#
#
# Test accuracy: 89 %
# Epoch:  117   Loss:  83.80436993390322   Train Accuracy : 97.446
#
#
# Test accuracy: 89 %
# Epoch:  118   Loss:  82.30450425297022   Train Accuracy : 97.592
#
#
# Test accuracy: 89 %
# Epoch:  119   Loss:  80.86865451186895   Train Accuracy : 97.734
#
#
# Test accuracy: 89 %
# Epoch:  120   Loss:  76.22259804606438   Train Accuracy : 97.982
#
#
# Test accuracy: 89 %
# Epoch:  121   Loss:  74.19478214532137   Train Accuracy : 98.198
#
#
# Test accuracy: 89 %
# Epoch:  122   Loss:  73.33844347298145   Train Accuracy : 98.08
#
#
# Test accuracy: 89 %
# Epoch:  123   Loss:  72.63965030014515   Train Accuracy : 98.242
#
#
# Test accuracy: 90 %
# Epoch:  124   Loss:  72.18507269024849   Train Accuracy : 98.256
#
#
# Test accuracy: 89 %
# Epoch:  125   Loss:  70.8610670119524   Train Accuracy : 98.348
#
#
# Test accuracy: 89 %
# Epoch:  126   Loss:  70.61223255097866   Train Accuracy : 98.338
#
#
# Test accuracy: 89 %
# Epoch:  127   Loss:  69.18761955946684   Train Accuracy : 98.448
#
#
# Test accuracy: 90 %
# Epoch:  128   Loss:  68.52806429564953   Train Accuracy : 98.462
#
#
# Test accuracy: 90 %
# Epoch:  129   Loss:  69.251894146204   Train Accuracy : 98.344
#
#
# Test accuracy: 89 %
# Epoch:  130   Loss:  67.44074862450361   Train Accuracy : 98.538
#
#
# Test accuracy: 90 %
# Epoch:  131   Loss:  67.99514962732792   Train Accuracy : 98.494
#
#
# Test accuracy: 90 %
# Epoch:  132   Loss:  67.6522392258048   Train Accuracy : 98.488
#
#
# Test accuracy: 89 %
# Epoch:  133   Loss:  66.97397497296333   Train Accuracy : 98.514
#
#
# Test accuracy: 90 %
# Epoch:  134   Loss:  66.75584353879094   Train Accuracy : 98.516
#
#
# Test accuracy: 89 %
# Epoch:  135   Loss:  66.60418878495693   Train Accuracy : 98.46
#
#
# Test accuracy: 90 %
# Epoch:  136   Loss:  67.48082293570042   Train Accuracy : 98.508
#
#
# Test accuracy: 89 %
# Epoch:  137   Loss:  66.33543496578932   Train Accuracy : 98.496
#
#
# Test accuracy: 89 %
# Epoch:  138   Loss:  66.79625999182463   Train Accuracy : 98.496
#
#
# Test accuracy: 89 %
# Epoch:  139   Loss:  66.9162886440754   Train Accuracy : 98.49
#
#
# Test accuracy: 89 %
# Epoch:  140   Loss:  62.64806377887726   Train Accuracy : 98.746
#
#
# Test accuracy: 89 %
# Epoch:  141   Loss:  61.24726064875722   Train Accuracy : 98.836
#
#
# Test accuracy: 90 %
# Epoch:  142   Loss:  61.346954986453056   Train Accuracy : 98.842
#
#
# Test accuracy: 89 %
# Epoch:  143   Loss:  61.002618089318275   Train Accuracy : 98.874
#
#
# Test accuracy: 89 %
# Epoch:  144   Loss:  60.780491068959236   Train Accuracy : 98.852
#
#
# Test accuracy: 90 %
# Epoch:  145   Loss:  59.56582469493151   Train Accuracy : 98.908
#
#
# Test accuracy: 90 %
# Epoch:  146   Loss:  59.49561835825443   Train Accuracy : 98.96
#
#
# Test accuracy: 89 %
# Epoch:  147   Loss:  60.22731411084533   Train Accuracy : 98.908
#
#
# Test accuracy: 90 %
# Epoch:  148   Loss:  58.08965975046158   Train Accuracy : 99.038
#
#
# Test accuracy: 90 %
# Epoch:  149   Loss:  59.196388732641935   Train Accuracy : 98.984
#
#
# Test accuracy: 90 %
# Epoch:  150   Loss:  58.63457453995943   Train Accuracy : 98.994
#
#
# Test accuracy: 90 %
# Epoch:  151   Loss:  59.07029816508293   Train Accuracy : 98.946
#
#
# Test accuracy: 90 %
# Epoch:  152   Loss:  60.15220867469907   Train Accuracy : 98.888
#
#
# Test accuracy: 90 %

# %%
#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 90 %
# 90.25
# Accuracy of plane : 93 %
# Accuracy of   car : 96 %
# Accuracy of  bird : 86 %
# Accuracy of   cat : 74 %
# Accuracy of  deer : 89 %
# Accuracy of   dog : 87 %
# Accuracy of  frog : 92 %
# Accuracy of horse : 96 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 100 %

# %%
'''  
The image lies between [0,1] but since I have trained the whole network on normalized input, Therefore
the min_val = -2.117 and max_val = 2.64 and not {0,1}
'''

# FGSM attack code
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, -2.117, 2.64)
    # Return the perturbed image
    return perturbed_image

def test( model, device, test_loader, epsilon ):

    # Accuracy counter
    correct = 0
    adv_examples = []

    # Loop over all examples in test set
    for data, target in test_loader:

        # Send the data and label to the device
        data, target = data.to(device), target.to(device)

        # Set requires_grad attribute of tensor. Important for Attack
        data.requires_grad = True

        # Forward pass the data through the model
        output = model(data)
        init_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability

        # If the initial prediction is wrong, dont bother attacking, just move on
        #if init_pred.item() != target.item():
        #    continue

        # Calculate the loss
        loss = F.nll_loss(output, target)

        # Zero all existing gradients
        model.zero_grad()

        # Calculate gradients of model in backward pass
        loss.backward()

        # Collect datagrad
        data_grad = data.grad.data

        # Call FGSM Attack
        perturbed_data = fgsm_attack(data, epsilon, data_grad)

        # Re-classify the perturbed image
        output = model(perturbed_data)

        # Check for success
        final_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        for i in range(0,len(final_pred)-1):
            if final_pred[i].sub(target[i]) == 0:
                correct += 1
                # Special case for saving 0 epsilon examples
                if (epsilon == 0) and (len(adv_examples) < 5):
                    adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                    adv_examples.append( (init_pred[i], final_pred[i], adv_ex) )
            else:
                # Save some adv examples for visualization later
                if len(adv_examples) < 5:
                    adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                    adv_examples.append( (init_pred[i], final_pred[i], adv_ex) )

    # Calculate final accuracy for this epsilon
    final_acc = correct/float(len(test_loader))
    print("Epsilon: {}\tTest Accuracy = {} / {} = {}".format(epsilon, correct, len(test_loader), final_acc))

    # Return the accuracy and an adversarial example
    return final_acc, adv_examples

# %%
#evaluate model
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = model(images.cuda())
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.cuda()).sum().item()

print('Accuracy on the test dataset is: %f %%' % (
    100 * correct / total))
# Out:
# Accuracy on the test dataset is: 90.250000 %

# %%
accuracies = []
examples = []
epsilons = [0, .05, .1, .15, .2, .25, .3]

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
use_cuda=True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

# Run test for each epsilon
for eps in epsilons:
    acc, ex = test(model, device, testloader, eps)
    accuracies.append(acc)
    examples.append(ex)
# Out:
# CUDA Available:  True
# Epsilon: 0	Test Accuracy = 8936 / 100 = 89.36
# Epsilon: 0.05	Test Accuracy = 5648 / 100 = 56.48
# Epsilon: 0.1	Test Accuracy = 5006 / 100 = 50.06
# Epsilon: 0.15	Test Accuracy = 4771 / 100 = 47.71
# Epsilon: 0.2	Test Accuracy = 4600 / 100 = 46.0
# Epsilon: 0.25	Test Accuracy = 4446 / 100 = 44.46
# Epsilon: 0.3	Test Accuracy = 4273 / 100 = 42.73

# %%
plt.figure(figsize=(5,5))
plt.plot(epsilons, torch.tensor(accuracies).div(100), "*-")
plt.yticks(np.arange(0, 1.1, step=0.1))
plt.xticks(np.arange(0, .35, step=0.05))
plt.title("Accuracy vs Epsilon")
plt.xlabel("Epsilon")
plt.ylabel("Accuracy")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

epsilons = [0, .05, .1, .15, .2, .25, .3]
accuracies = np.divide(accuracies, 100)
accuracies1 = [0.8881, 0.2799, 0.1636, 0.1375, 0.1325, 0.1327, 0.1359]
accuraciesA = [86.03,
45.05,
31.15,
26.59,
24.5,
23.01,
21.35,
]
accuraciesB = [79.62,
36.57,
21.01,
15.78,
13.75,
12.67,
12.38,
]
accuraciesC = [84.57,
36.22,
25.87,
22.22,
20.14,
19.32,
19.39,
]
accuraciesD = [86.99,
41.49,
31.85,
28.82,
27.48,
25.98,
24.86,
]
accuraciesA = np.divide(accuraciesA, 100)
accuraciesB = np.divide(accuraciesB, 100)
accuraciesC = np.divide(accuraciesC, 100)
accuraciesD = np.divide(accuraciesD, 100)
plt.figure(figsize=(5,5))
plt.plot(epsilons, accuracies1, "*-", label = "Baseline VGG16")
plt.yticks(np.arange(0, 1.1, step=0.1))
plt.plot(epsilons, accuracies, "*-", label = "FlexiVGG16(2)")
plt.xticks(np.arange(0, .35, step=0.05))
plt.plot(epsilons, accuraciesA, "*-", label = "A")
plt.xticks(np.arange(0, .35, step=0.05))
plt.plot(epsilons, accuraciesB, "*-", label = "B")
plt.xticks(np.arange(0, .35, step=0.05))
plt.plot(epsilons, accuraciesC, "*-", label = "C")
plt.xticks(np.arange(0, .35, step=0.05))
plt.plot(epsilons, accuraciesD, "*-", label = "D")
plt.xticks(np.arange(0, .35, step=0.05))
#plt.plot(epsilons, accuracies3, "*-", label = "FlexiVGG16_batch_indep_100epochs")
plt.title("FGSM Testing Accuracy vs Epsilon")
plt.xlabel("Epsilon")
plt.ylabel("Testing Accuracy")
plt.legend()
#plt.savefig('./figures/fgsm_testing_results.png', format='png')
plt.show()
