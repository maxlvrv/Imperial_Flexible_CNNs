# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

from models.VGG16_with_flex_v9 import *


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
#  ship plane  ship plane

# %%
# =============================================================== Model initialisation, Loss function and Optimizer =====================================
model = VGG16()
if torch.cuda.is_available():
  model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma = 0.7)

# ======================== Function to get the test accuracy ===============================================================================
def test():
  correct = 0
  total = 0
  model.train(False)
  with torch.no_grad():
    for i,(images,labels)in enumerate(testloader):
      if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
      outputs = model(Variable(images))
      labels = Variable(labels)
      _,predicted = outputs.max(1)
      total += labels.size(0)
      correct += (predicted.eq(labels)).sum().item()
    print('Test accuracy: %d %%' % (
  100 * correct / total))
  return 100*(correct/total)

#======================================================= Training =========================================================================
num_epochs = 160  # Train for 150 epochs
start_epoch = 0

total_step = len(trainloader)
train_loss = []  # Store the train_loss per epoch
test_accuracy = [] # Store the test_accuracy per epoch
for epoch in range(start_epoch,num_epochs+1):
  model.train(True)
  epoch_loss  = 0
  i_count = 0
  acc_total = 0
  for i,(images,labels) in enumerate(trainloader):
    if torch.cuda.is_available():
      images = images.cuda()
      labels = labels.cuda()
    labels = Variable(labels)
    optimizer.zero_grad()
    outputs = model(Variable(images))
    loss = criterion(outputs,labels)
    epoch_loss += loss.item()
    loss.backward()
    optimizer.step()
    _,predicted = outputs.max(1)
    denom = labels.size(0)
    correct = predicted.eq(labels).sum().item()
    acc = 100*(correct/denom)
    acc_total += acc
    i_count = i_count + 1
    
    #if(i%20 == 0):  # Print the loss per 20 iterations
      #print("Epoch: ",epoch," ","Iteration: ",i," loss: ",loss.item()," Train_iter Accuracy: ",acc)
  schedule.step()
  train_loss.append(epoch_loss)
  print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
  print('\n')
  test_acc = test()      # Print the test accuracy per epoch
  test_accuracy.append(test_acc)
  
  if(epoch%50 == 0):       # Save the model every 50 epoch
    state = {
        'model': model.state_dict(),
        'acc' : test_acc,
        'optim':optimizer.state_dict(),
        'epoch' : epoch
    }
    path = './models/VGG16-flex-v9-block4-' + 'model_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
    torch.save(state,path)
# Out:
# Epoch:  0   Loss:  1076.7974346876144   Train Accuracy : 17.072
#
#
# Test accuracy: 14 %
# Epoch:  1   Loss:  955.3049595355988   Train Accuracy : 24.286
#
#
# Test accuracy: 20 %
# Epoch:  2   Loss:  894.8350373506546   Train Accuracy : 28.91
#
#
# Test accuracy: 27 %
# Epoch:  3   Loss:  858.3961623907089   Train Accuracy : 31.952
#
#
# Test accuracy: 29 %
# Epoch:  4   Loss:  826.4933625459671   Train Accuracy : 35.662
#
#
# Test accuracy: 31 %
# Epoch:  5   Loss:  794.582013964653   Train Accuracy : 39.026
#
#
# Test accuracy: 41 %
# Epoch:  6   Loss:  759.662034869194   Train Accuracy : 42.582
#
#
# Test accuracy: 45 %
# Epoch:  7   Loss:  730.6840314865112   Train Accuracy : 46.348
#
#
# Test accuracy: 51 %
# Epoch:  8   Loss:  696.3842951059341   Train Accuracy : 50.254
#
#
# Test accuracy: 58 %
# Epoch:  9   Loss:  662.1965190172195   Train Accuracy : 54.24
#
#
# Test accuracy: 60 %
# Epoch:  10   Loss:  631.6292366981506   Train Accuracy : 57.112
#
#
# Test accuracy: 61 %
# Epoch:  11   Loss:  607.4748629927635   Train Accuracy : 59.414
#
#
# Test accuracy: 65 %
# Epoch:  12   Loss:  581.8238473534584   Train Accuracy : 61.68
#
#
# Test accuracy: 67 %
# Epoch:  13   Loss:  562.1598034501076   Train Accuracy : 63.122
#
#
# Test accuracy: 69 %
# Epoch:  14   Loss:  544.6447077989578   Train Accuracy : 64.75
#
#
# Test accuracy: 71 %
# Epoch:  15   Loss:  527.8093422055244   Train Accuracy : 66.152
#
#
# Test accuracy: 71 %
# Epoch:  16   Loss:  511.9311198592186   Train Accuracy : 67.708
#
#
# Test accuracy: 73 %
# Epoch:  17   Loss:  494.9797133207321   Train Accuracy : 68.686
#
#
# Test accuracy: 75 %
# Epoch:  18   Loss:  481.2205622792244   Train Accuracy : 69.9
#
#
# Test accuracy: 75 %
# Epoch:  19   Loss:  468.6385017633438   Train Accuracy : 71.034
#
#
# Test accuracy: 76 %
# Epoch:  20   Loss:  444.71674650907516   Train Accuracy : 73.062
#
#
# Test accuracy: 77 %
# Epoch:  21   Loss:  426.9969668984413   Train Accuracy : 74.004
#
#
# Test accuracy: 78 %
# Epoch:  22   Loss:  418.73084288835526   Train Accuracy : 74.932
#
#
# Test accuracy: 79 %
# Epoch:  23   Loss:  412.70179599523544   Train Accuracy : 75.378
#
#
# Test accuracy: 79 %
# Epoch:  24   Loss:  406.03182858228683   Train Accuracy : 76.026
#
#
# Test accuracy: 80 %
# Epoch:  25   Loss:  396.3071093559265   Train Accuracy : 76.672
#
#
# Test accuracy: 80 %
# Epoch:  26   Loss:  388.06903582811356   Train Accuracy : 77.472
#
#
# Test accuracy: 81 %
# Epoch:  27   Loss:  383.1340224146843   Train Accuracy : 77.964
#
#
# Test accuracy: 82 %
# Epoch:  28   Loss:  374.1182852983475   Train Accuracy : 78.482
#
#
# Test accuracy: 81 %
# Epoch:  29   Loss:  368.0958164334297   Train Accuracy : 78.9
#
#
# Test accuracy: 82 %
# Epoch:  30   Loss:  362.50027361512184   Train Accuracy : 79.442
#
#
# Test accuracy: 82 %
# Epoch:  31   Loss:  355.77427995204926   Train Accuracy : 80.05
#
#
# Test accuracy: 82 %
# Epoch:  32   Loss:  352.39910516142845   Train Accuracy : 80.064
#
#
# Test accuracy: 83 %
# Epoch:  33   Loss:  346.2741784453392   Train Accuracy : 80.672
#
#
# Test accuracy: 83 %
# Epoch:  34   Loss:  345.6428214907646   Train Accuracy : 80.716
#
#
# Test accuracy: 83 %
# Epoch:  35   Loss:  335.19714641571045   Train Accuracy : 81.462
#
#
# Test accuracy: 83 %
# Epoch:  36   Loss:  332.86248710751534   Train Accuracy : 81.468
#
#
# Test accuracy: 84 %
# Epoch:  37   Loss:  331.5633293688297   Train Accuracy : 81.726
#
#
# Test accuracy: 84 %
# Epoch:  38   Loss:  323.38138750195503   Train Accuracy : 82.25
#
#
# Test accuracy: 83 %
# Epoch:  39   Loss:  312.2732291519642   Train Accuracy : 82.984
#
#
# Test accuracy: 85 %
# Epoch:  40   Loss:  303.4516631066799   Train Accuracy : 83.746
#
#
# Test accuracy: 85 %
# Epoch:  41   Loss:  289.0518324673176   Train Accuracy : 84.642
#
#
# Test accuracy: 86 %
# Epoch:  42   Loss:  287.05500918626785   Train Accuracy : 84.746
#
#
# Test accuracy: 85 %
# Epoch:  43   Loss:  282.73673382401466   Train Accuracy : 84.952
#
#
# Test accuracy: 85 %
# Epoch:  44   Loss:  282.7017821967602   Train Accuracy : 85.194
#
#
# Test accuracy: 86 %
# Epoch:  45   Loss:  279.18361070752144   Train Accuracy : 85.142
#
#
# Test accuracy: 86 %
# Epoch:  46   Loss:  275.35223665833473   Train Accuracy : 85.578
#
#
# Test accuracy: 86 %
# Epoch:  47   Loss:  270.9853411912918   Train Accuracy : 86.024
#
#
# Test accuracy: 86 %
# Epoch:  48   Loss:  269.20006066560745   Train Accuracy : 86.09
#
#
# Test accuracy: 86 %
# Epoch:  49   Loss:  264.6244111061096   Train Accuracy : 86.22
#
#
# Test accuracy: 86 %
# Epoch:  50   Loss:  261.1878764331341   Train Accuracy : 86.54
#
#
# Test accuracy: 86 %
# Epoch:  51   Loss:  260.38800686597824   Train Accuracy : 86.522
#
#
# Test accuracy: 86 %
# Epoch:  52   Loss:  258.72691184282303   Train Accuracy : 86.574
#
#
# Test accuracy: 87 %
# Epoch:  53   Loss:  256.2570533156395   Train Accuracy : 86.76
#
#
# Test accuracy: 86 %
# Epoch:  54   Loss:  255.05841067433357   Train Accuracy : 87.196
#
#
# Test accuracy: 86 %
# Epoch:  55   Loss:  248.33657586574554   Train Accuracy : 87.552
#
#
# Test accuracy: 86 %
# Epoch:  56   Loss:  248.1919039785862   Train Accuracy : 87.236
#
#
# Test accuracy: 87 %
# Epoch:  57   Loss:  248.10912838578224   Train Accuracy : 87.41
#
#
# Test accuracy: 86 %
# Epoch:  58   Loss:  244.90563610196114   Train Accuracy : 87.576
#
#
# Test accuracy: 87 %
# Epoch:  59   Loss:  242.71667447686195   Train Accuracy : 87.67
#
#
# Test accuracy: 87 %
# Epoch:  60   Loss:  225.82757914066315   Train Accuracy : 88.872
#
#
# Test accuracy: 87 %
# Epoch:  61   Loss:  220.2518800497055   Train Accuracy : 89.326
#
#
# Test accuracy: 88 %
# Epoch:  62   Loss:  217.47605580091476   Train Accuracy : 89.322
#
#
# Test accuracy: 87 %
# Epoch:  63   Loss:  214.62263152003288   Train Accuracy : 89.65
#
#
# Test accuracy: 88 %
# Epoch:  64   Loss:  212.80088099837303   Train Accuracy : 89.728
#
#
# Test accuracy: 88 %
# Epoch:  65   Loss:  208.6518803089857   Train Accuracy : 89.912
#
#
# Test accuracy: 87 %
# Epoch:  66   Loss:  206.54021188616753   Train Accuracy : 90.122
#
#
# Test accuracy: 88 %
# Epoch:  67   Loss:  205.7130817770958   Train Accuracy : 90.05
#
#
# Test accuracy: 88 %
# Epoch:  68   Loss:  203.37979543209076   Train Accuracy : 90.38
#
#
# Test accuracy: 88 %
# Epoch:  69   Loss:  205.43383459746838   Train Accuracy : 90.14
#
#
# Test accuracy: 88 %
# Epoch:  70   Loss:  201.40922331809998   Train Accuracy : 90.438
#
#
# Test accuracy: 88 %
# Epoch:  71   Loss:  200.55607044696808   Train Accuracy : 90.548
#
#
# Test accuracy: 88 %
# Epoch:  72   Loss:  198.65919518470764   Train Accuracy : 90.636
#
#
# Test accuracy: 88 %
# Epoch:  73   Loss:  198.96425937116146   Train Accuracy : 90.54
#
#
# Test accuracy: 87 %
# Epoch:  74   Loss:  196.20651921629906   Train Accuracy : 90.696
#
#
# Test accuracy: 88 %
# Epoch:  75   Loss:  195.7588018476963   Train Accuracy : 90.75
#
#
# Test accuracy: 88 %
# Epoch:  76   Loss:  193.19251814484596   Train Accuracy : 90.984
#
#
# Test accuracy: 88 %
# Epoch:  77   Loss:  192.90608808398247   Train Accuracy : 90.948
#
#
# Test accuracy: 88 %
# Epoch:  78   Loss:  188.1858507245779   Train Accuracy : 91.174
#
#
# Test accuracy: 88 %
# Epoch:  79   Loss:  188.50375066697598   Train Accuracy : 91.178
#
#
# Test accuracy: 88 %
# Epoch:  80   Loss:  179.09688521921635   Train Accuracy : 91.904
#
#
# Test accuracy: 88 %
# Epoch:  81   Loss:  171.31679990887642   Train Accuracy : 92.456
#
#
# Test accuracy: 88 %
# Epoch:  82   Loss:  167.68578207492828   Train Accuracy : 92.682
#
#
# Test accuracy: 88 %
# Epoch:  83   Loss:  165.60816475749016   Train Accuracy : 92.686
#
#
# Test accuracy: 88 %
# Epoch:  84   Loss:  165.50450278818607   Train Accuracy : 92.676
#
#
# Test accuracy: 88 %
# Epoch:  85   Loss:  163.60846570134163   Train Accuracy : 92.898
#
#
# Test accuracy: 88 %
# Epoch:  86   Loss:  162.15011717379093   Train Accuracy : 92.946
#
#
# Test accuracy: 89 %
# Epoch:  87   Loss:  159.1671842932701   Train Accuracy : 93.066
#
#
# Test accuracy: 89 %
# Epoch:  88   Loss:  159.96188507974148   Train Accuracy : 93.01
#
#
# Test accuracy: 88 %
# Epoch:  89   Loss:  157.59025831520557   Train Accuracy : 93.334
#
#
# Test accuracy: 88 %
# Epoch:  90   Loss:  158.67569011449814   Train Accuracy : 93.182
#
#
# Test accuracy: 89 %
# Epoch:  91   Loss:  156.44277648627758   Train Accuracy : 93.414
#
#
# Test accuracy: 88 %
# Epoch:  92   Loss:  157.5570307970047   Train Accuracy : 93.246
#
#
# Test accuracy: 88 %
# Epoch:  93   Loss:  154.2745081782341   Train Accuracy : 93.444
#
#
# Test accuracy: 89 %
# Epoch:  94   Loss:  155.30334417521954   Train Accuracy : 93.282
#
#
# Test accuracy: 88 %
# Epoch:  95   Loss:  151.0296441912651   Train Accuracy : 93.604
# Test accuracy: 88 %
# Epoch:  96   Loss:  152.3049921244383   Train Accuracy : 93.38
#
#
# Test accuracy: 88 %
# Epoch:  97   Loss:  151.59838086366653   Train Accuracy : 93.598
#
#
# Test accuracy: 88 %
# Epoch:  98   Loss:  150.04446280747652   Train Accuracy : 93.596
#
#
# Test accuracy: 88 %
# Epoch:  99   Loss:  148.49539268016815   Train Accuracy : 93.698
#
#
# Test accuracy: 88 %
# Epoch:  100   Loss:  140.81823559105396   Train Accuracy : 94.226
#
#
# Test accuracy: 89 %
# Epoch:  101   Loss:  133.30828446149826   Train Accuracy : 94.698
#
#
# Test accuracy: 89 %
# Epoch:  102   Loss:  130.9363508671522   Train Accuracy : 94.91
#
#
# Test accuracy: 88 %
# Epoch:  103   Loss:  130.58799503743649   Train Accuracy : 94.896
#
#
# Test accuracy: 89 %
# Epoch:  104   Loss:  128.42476737499237   Train Accuracy : 95.07
#
#
# Test accuracy: 89 %
# Epoch:  105   Loss:  128.0406803637743   Train Accuracy : 95.052
#
#
# Test accuracy: 89 %
# Epoch:  106   Loss:  128.19532890617847   Train Accuracy : 95.122
#
#
# Test accuracy: 89 %
# Epoch:  107   Loss:  124.6130655258894   Train Accuracy : 95.34
#
#
# Test accuracy: 89 %
# Epoch:  108   Loss:  125.52295736223459   Train Accuracy : 95.234
#
#
# Test accuracy: 89 %
# Epoch:  109   Loss:  125.97177270054817   Train Accuracy : 95.104
#
#
# Test accuracy: 89 %
# Epoch:  110   Loss:  124.2833251208067   Train Accuracy : 95.264
#
#
# Test accuracy: 89 %
# Epoch:  111   Loss:  124.33147801458836   Train Accuracy : 95.322
#
#
# Test accuracy: 89 %
# Epoch:  112   Loss:  123.27187482267618   Train Accuracy : 95.232
#
#
# Test accuracy: 89 %
# Epoch:  113   Loss:  119.61626571416855   Train Accuracy : 95.436
#
#
# Test accuracy: 89 %
# Epoch:  114   Loss:  121.87090590596199   Train Accuracy : 95.47
#
#
# Test accuracy: 89 %
# Epoch:  115   Loss:  120.9390227869153   Train Accuracy : 95.44
#
#
# Test accuracy: 89 %
# Epoch:  116   Loss:  121.33402740955353   Train Accuracy : 95.36
#
#
# Test accuracy: 89 %
# Epoch:  117   Loss:  119.78847135603428   Train Accuracy : 95.462
#
#
# Test accuracy: 88 %
# Epoch:  118   Loss:  119.00615983456373   Train Accuracy : 95.524
#
#
# Test accuracy: 89 %
# Epoch:  119   Loss:  119.2356398627162   Train Accuracy : 95.524
#
#
# Test accuracy: 89 %
# Epoch:  120   Loss:  113.42002221941948   Train Accuracy : 95.85
#
#
# Test accuracy: 89 %
# Epoch:  121   Loss:  109.63467073440552   Train Accuracy : 96.154
#
#
# Test accuracy: 89 %
# Epoch:  122   Loss:  108.54633873701096   Train Accuracy : 96.196
#
#
# Test accuracy: 89 %
# Epoch:  123   Loss:  107.3972368016839   Train Accuracy : 96.312
#
#
# Test accuracy: 89 %
# Epoch:  124   Loss:  104.73673047870398   Train Accuracy : 96.464
#
#
# Test accuracy: 89 %
# Epoch:  125   Loss:  104.83894207328558   Train Accuracy : 96.468
#
#
# Test accuracy: 89 %
# Epoch:  126   Loss:  104.93155563622713   Train Accuracy : 96.348
#
#
# Test accuracy: 89 %
# Epoch:  127   Loss:  102.74662292003632   Train Accuracy : 96.52
#
#
# Test accuracy: 89 %
# Epoch:  128   Loss:  102.19668500870466   Train Accuracy : 96.512
#
#
# Test accuracy: 89 %
# Epoch:  129   Loss:  99.77273108065128   Train Accuracy : 96.774
#
#
# Test accuracy: 89 %
# Epoch:  130   Loss:  99.1061719879508   Train Accuracy : 96.892
#
#
# Test accuracy: 89 %
# Epoch:  131   Loss:  101.11140328645706   Train Accuracy : 96.714
#
#
# Test accuracy: 89 %
# Epoch:  132   Loss:  99.49692863970995   Train Accuracy : 96.77
#
#
# Test accuracy: 89 %
# Epoch:  133   Loss:  99.39914777129889   Train Accuracy : 96.788
#
#
# Test accuracy: 89 %
# Epoch:  134   Loss:  99.03733039647341   Train Accuracy : 96.76
#
#
# Test accuracy: 89 %
# Epoch:  135   Loss:  95.59867416322231   Train Accuracy : 97.022
#
#
# Test accuracy: 89 %
# Epoch:  136   Loss:  98.67180032283068   Train Accuracy : 96.78
#
#
# Test accuracy: 89 %
# Epoch:  137   Loss:  97.16635857522488   Train Accuracy : 96.75
#
#
# Test accuracy: 89 %
# Epoch:  138   Loss:  96.15341107547283   Train Accuracy : 96.866
#
#
# Test accuracy: 89 %
# Epoch:  139   Loss:  95.62716207653284   Train Accuracy : 96.92
#
#
# Test accuracy: 89 %
# Epoch:  140   Loss:  92.49586381018162   Train Accuracy : 97.18
#
#
# Test accuracy: 89 %
# Epoch:  141   Loss:  90.20052242279053   Train Accuracy : 97.312
#
#
# Test accuracy: 89 %
# Epoch:  142   Loss:  89.41252898424864   Train Accuracy : 97.368
#
#
# Test accuracy: 90 %
# Epoch:  143   Loss:  85.85240164399147   Train Accuracy : 97.52
#
#
# Test accuracy: 89 %
# Epoch:  144   Loss:  86.37091328203678   Train Accuracy : 97.534
#
#
# Test accuracy: 89 %
# Epoch:  145   Loss:  84.45945199579   Train Accuracy : 97.62
#
#
# Test accuracy: 89 %
# Epoch:  146   Loss:  85.99575366079807   Train Accuracy : 97.496
#
#
# Test accuracy: 89 %
# Epoch:  147   Loss:  83.8118494078517   Train Accuracy : 97.594
#
#
# Test accuracy: 89 %
# Epoch:  148   Loss:  84.78198485821486   Train Accuracy : 97.566
#
#
# Test accuracy: 89 %
# Epoch:  149   Loss:  84.23947893828154   Train Accuracy : 97.694
#
#
# Test accuracy: 90 %
# Epoch:  150   Loss:  81.68280267715454   Train Accuracy : 97.862
#
#
# Test accuracy: 89 %
# Epoch:  151   Loss:  84.59668175131083   Train Accuracy : 97.634
#
#
# Test accuracy: 89 %
# Epoch:  152   Loss:  82.92469412088394   Train Accuracy : 97.708
#
#
# Test accuracy: 89 %
# Epoch:  153   Loss:  82.17717662453651   Train Accuracy : 97.792
#
#
# Test accuracy: 89 %
# Epoch:  154   Loss:  80.80809077620506   Train Accuracy : 97.904
#
#
# Test accuracy: 89 %
# Epoch:  155   Loss:  83.22194841504097   Train Accuracy : 97.678
#
#
# Test accuracy: 89 %
# Epoch:  156   Loss:  82.02378103137016   Train Accuracy : 97.776
#
#
# Test accuracy: 89 %
# Epoch:  157   Loss:  78.51392823457718   Train Accuracy : 97.862
#
#
# Test accuracy: 89 %
# Epoch:  158   Loss:  81.79246997833252   Train Accuracy : 97.778
#
#
# Test accuracy: 89 %
# Epoch:  159   Loss:  78.51206973940134   Train Accuracy : 97.926
#
#
# Test accuracy: 89 %
# Epoch:  160   Loss:  79.30546140670776   Train Accuracy : 97.888
#
#
# Test accuracy: 89 %

# %%
#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 89 %
# 89.85
# Accuracy of plane : 86 %
# Accuracy of   car : 96 %
# Accuracy of  bird : 86 %
# Accuracy of   cat : 69 %
# Accuracy of  deer : 89 %
# Accuracy of   dog : 90 %
# Accuracy of  frog : 92 %
# Accuracy of horse : 93 %
# Accuracy of  ship : 91 %
# Accuracy of truck : 100 %

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} trainable parameters.')
# Out:
# 14,783,838 total parameters.
# 14,783,838 trainable parameters.
