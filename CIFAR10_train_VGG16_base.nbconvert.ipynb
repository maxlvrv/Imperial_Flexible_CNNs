# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# ================================================= Flexible Layer ================================================================================

    
class FlexiLayer(nn.Module): # class FlexiLayer(nn.Conv2d):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 padding=0):
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        super(FlexiLayer, self).__init__()
        
        self.t_1 = nn.Conv2d(self.in_channels, self.out_channels, self.kernel_size, self.stride, self.padding)
        self.t_2 = nn.MaxPool2d(self.kernel_size, self.stride, self.padding) # get max result with the same kernel size
        self.m = nn.Sigmoid()
        
        self.threshold1 = Variable(torch.randn((1, self.out_channels, 30, 30)))
        
        self.thresh_mean = []
        
    def forward(self, t):
        
        #self.threshold1.expand(t.size(0), self.out_channels, 30, 30)
        
        
        #cond = torch.sub(self.t_2(t), self.threshold1.cuda())
        #t_2_2 = self.m(cond*50)*self.t_2(t) # 
        #t_1_1 = self.m(cond*(-50))*self.t_1(t) # 
        #t = torch.add(t_2_2, t_1_1)
        
        return self.t_1(t)

    # ================================================= VGG-16 Network ================================================================================
class VGG16(nn.Module):
  def __init__(self):
    super(VGG16,self).__init__()

    self.block1 = nn.Sequential(
                  nn.Conv2d(in_channels = 3,out_channels = 64,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(64),
                  nn.ReLU(),
                  FlexiLayer(in_channels = 64,out_channels = 64,kernel_size = 3, padding =0),
                  nn.BatchNorm2d(64),
                  nn.ReLU(),
                  #nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.3))

    self.block2 = nn.Sequential(
                  nn.Conv2d(in_channels = 64,out_channels = 128,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(128),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 128,out_channels = 128,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(128),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.4))

    self.block3 = nn.Sequential(
                  nn.Conv2d(in_channels = 128,out_channels = 256,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(256),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(256),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(256),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.4))

    self.block4 = nn.Sequential(
                  nn.Conv2d(in_channels = 256,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2) ,
                  nn.Dropout2d(0.4))

    self.block5 = nn.Sequential(
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                  nn.BatchNorm2d(512),
                  nn.ReLU(),
                  nn.MaxPool2d(kernel_size=2, stride=2),
                  nn.Dropout2d(0.5) )

    self.fc =     nn.Sequential(
                  nn.Linear(512,100),
                  nn.Dropout(0.5),
                  nn.BatchNorm1d(100),
                  nn.ReLU(),
                  nn.Dropout(0.5),
                  nn.Linear(100,10), )
                  
                  


  def forward(self,x):
    out = self.block1(x)
    out = self.block2(out)
    out = self.block3(out)
    out = self.block4(out)
    out = self.block5(out)
    out = out.view(out.size(0),-1)
    out = self.fc(out)

    return out

# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

#from models.VGG16_with_flex_v5 import *


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
# horse   car   dog horse

# %%
# =============================================================== Model initialisation, Loss function and Optimizer =====================================
model = VGG16()
if torch.cuda.is_available():
  model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma = 0.7)

total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} trainable parameters.')
# Out:
# 14,775,646 total parameters.
# 14,775,646 trainable parameters.

# %%
# ======================== Function to get the test accuracy ===============================================================================
def test():
  correct = 0
  total = 0
  model.train(False)
  with torch.no_grad():
    for i,(images,labels)in enumerate(testloader):
      if torch.cuda.is_available():
        images = images.cuda()
        labels = labels.cuda()
      outputs = model(Variable(images))
      labels = Variable(labels)
      _,predicted = outputs.max(1)
      total += labels.size(0)
      correct += (predicted.eq(labels)).sum().item()
    print('Test accuracy: %d %%' % (
  100 * correct / total))
  return 100*(correct/total)

#======================================================= Training =========================================================================
num_epochs = 152  # Train for 150 epochs
start_epoch = 0

total_step = len(trainloader)
train_loss = []  # Store the train_loss per epoch
test_accuracy = [] # Store the test_accuracy per epoch
for epoch in range(start_epoch,num_epochs+1):
  model.train(True)
  epoch_loss  = 0
  i_count = 0
  acc_total = 0
  for i,(images,labels) in enumerate(trainloader):
    if torch.cuda.is_available():
      images = images.cuda()
      labels = labels.cuda()
    labels = Variable(labels)
    optimizer.zero_grad()
    outputs = model(Variable(images))
    loss = criterion(outputs,labels)
    epoch_loss += loss.item()
    loss.backward()
    optimizer.step()
    _,predicted = outputs.max(1)
    denom = labels.size(0)
    correct = predicted.eq(labels).sum().item()
    acc = 100*(correct/denom)
    acc_total += acc
    i_count = i_count + 1
    
    #if(i%20 == 0):  # Print the loss per 20 iterations
      #print("Epoch: ",epoch," ","Iteration: ",i," loss: ",loss.item()," Train_iter Accuracy: ",acc)
  schedule.step()
  train_loss.append(epoch_loss)
  print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
  print('\n')
  test_acc = test()      # Print the test accuracy per epoch
  test_accuracy.append(test_acc)
  
  if(epoch%150 == 0):       # Save the model every 50 epoch
    state = {
        'model': model.state_dict(),
        'acc' : test_acc,
        'optim':optimizer.state_dict(),
        'epoch' : epoch
    }
    path = './models/VGG16-BASE-nnmodule_' + 'model_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
    torch.save(state,path)
# Out:
# Epoch:  0   Loss:  1083.0164369344711   Train Accuracy : 16.938
#
#
# Test accuracy: 14 %
# Epoch:  1   Loss:  959.0720950365067   Train Accuracy : 25.772
#
#
# Test accuracy: 28 %
# Epoch:  2   Loss:  882.3012199401855   Train Accuracy : 32.888
#
#
# Test accuracy: 37 %
# Epoch:  3   Loss:  835.0617966651917   Train Accuracy : 37.448
#
#
# Test accuracy: 42 %
# Epoch:  4   Loss:  797.9766916036606   Train Accuracy : 41.102
#
#
# Test accuracy: 47 %
# Epoch:  5   Loss:  762.2134363651276   Train Accuracy : 44.986
#
#
# Test accuracy: 49 %
# Epoch:  6   Loss:  722.928818821907   Train Accuracy : 48.95
#
#
# Test accuracy: 54 %
# Epoch:  7   Loss:  682.103637099266   Train Accuracy : 52.648
#
#
# Test accuracy: 59 %
# Epoch:  8   Loss:  645.7850251197815   Train Accuracy : 55.864
#
#
# Test accuracy: 62 %
# Epoch:  9   Loss:  615.1085446476936   Train Accuracy : 58.952
#
#
# Test accuracy: 65 %
# Epoch:  10   Loss:  580.6536234617233   Train Accuracy : 61.658
#
#
# Test accuracy: 67 %
# Epoch:  11   Loss:  553.392973959446   Train Accuracy : 63.562
#
#
# Test accuracy: 69 %
# Epoch:  12   Loss:  532.9565110206604   Train Accuracy : 65.17
#
#
# Test accuracy: 70 %
# Epoch:  13   Loss:  508.24796026945114   Train Accuracy : 67.576
#
#
# Test accuracy: 71 %
# Epoch:  14   Loss:  485.9278375506401   Train Accuracy : 69.27
#
#
# Test accuracy: 74 %
# Epoch:  15   Loss:  473.08445954322815   Train Accuracy : 70.246
#
#
# Test accuracy: 74 %
# Epoch:  16   Loss:  452.70487290620804   Train Accuracy : 71.886
#
#
# Test accuracy: 77 %
# Epoch:  17   Loss:  431.55387711524963   Train Accuracy : 73.436
#
#
# Test accuracy: 78 %
# Epoch:  18   Loss:  421.8842397928238   Train Accuracy : 74.568
#
#
# Test accuracy: 79 %
# Epoch:  19   Loss:  405.01470762491226   Train Accuracy : 75.802
#
#
# Test accuracy: 79 %
# Epoch:  20   Loss:  378.40668880939484   Train Accuracy : 78.004
#
#
# Test accuracy: 81 %
# Epoch:  21   Loss:  361.41361784935   Train Accuracy : 79.022
#
#
# Test accuracy: 82 %
# Epoch:  22   Loss:  355.2634009718895   Train Accuracy : 79.65
#
#
# Test accuracy: 82 %
# Epoch:  23   Loss:  347.3640601336956   Train Accuracy : 80.43
#
#
# Test accuracy: 83 %
# Epoch:  24   Loss:  336.0731362104416   Train Accuracy : 81.184
#
#
# Test accuracy: 83 %
# Epoch:  25   Loss:  327.35629737377167   Train Accuracy : 81.62
#
#
# Test accuracy: 84 %
# Epoch:  26   Loss:  323.32206362485886   Train Accuracy : 81.922
#
#
# Test accuracy: 84 %
# Epoch:  27   Loss:  315.1621755063534   Train Accuracy : 82.528
#
#
# Test accuracy: 85 %
# Epoch:  28   Loss:  305.6455639600754   Train Accuracy : 83.232
#
#
# Test accuracy: 85 %
# Epoch:  29   Loss:  303.01707684993744   Train Accuracy : 83.356
#
#
# Test accuracy: 84 %
# Epoch:  30   Loss:  291.9969724416733   Train Accuracy : 84.076
#
#
# Test accuracy: 85 %
# Epoch:  31   Loss:  287.76919707655907   Train Accuracy : 84.326
#
#
# Test accuracy: 85 %
# Epoch:  32   Loss:  281.6667560636997   Train Accuracy : 84.752
#
#
# Test accuracy: 86 %
# Epoch:  33   Loss:  280.18860429525375   Train Accuracy : 84.968
#
#
# Test accuracy: 86 %
# Epoch:  34   Loss:  271.2297032773495   Train Accuracy : 85.298
#
#
# Test accuracy: 86 %
# Epoch:  35   Loss:  267.26170375943184   Train Accuracy : 85.728
#
#
# Test accuracy: 86 %
# Epoch:  36   Loss:  263.89216780662537   Train Accuracy : 85.89
#
#
# Test accuracy: 86 %
# Epoch:  37   Loss:  259.8460601866245   Train Accuracy : 86.432
#
#
# Test accuracy: 87 %
# Epoch:  38   Loss:  255.2071304321289   Train Accuracy : 86.548
#
#
# Test accuracy: 86 %
# Epoch:  39   Loss:  249.72992604970932   Train Accuracy : 87.062
#
#
# Test accuracy: 86 %
# Epoch:  40   Loss:  228.33054965734482   Train Accuracy : 88.258
#
#
# Test accuracy: 88 %
# Epoch:  41   Loss:  220.16009014844894   Train Accuracy : 88.994
#
#
# Test accuracy: 88 %
# Epoch:  42   Loss:  214.9532349407673   Train Accuracy : 89.344
#
#
# Test accuracy: 87 %
# Epoch:  43   Loss:  212.35281793773174   Train Accuracy : 89.472
#
#
# Test accuracy: 87 %
# Epoch:  44   Loss:  210.01687471568584   Train Accuracy : 89.498
#
#
# Test accuracy: 88 %
# Epoch:  45   Loss:  207.31257720291615   Train Accuracy : 89.742
#
#
# Test accuracy: 88 %
# Epoch:  46   Loss:  204.37826146185398   Train Accuracy : 90.024
#
#
# Test accuracy: 88 %
# Epoch:  47   Loss:  201.31773920357227   Train Accuracy : 90.212
#
#
# Test accuracy: 89 %
# Epoch:  48   Loss:  195.86370241641998   Train Accuracy : 90.658
#
#
# Test accuracy: 88 %
# Epoch:  49   Loss:  195.6165412068367   Train Accuracy : 90.518
#
#
# Test accuracy: 88 %
# Epoch:  50   Loss:  191.29423294961452   Train Accuracy : 90.922
#
#
# Test accuracy: 88 %
# Epoch:  51   Loss:  189.4028761088848   Train Accuracy : 91.018
#
#
# Test accuracy: 88 %
# Epoch:  52   Loss:  188.03553143143654   Train Accuracy : 90.998
#
#
# Test accuracy: 88 %
# Epoch:  53   Loss:  187.12603630125523   Train Accuracy : 90.944
#
#
# Test accuracy: 88 %
# Epoch:  54   Loss:  183.76273131370544   Train Accuracy : 91.268
#
#
# Test accuracy: 88 %
# Epoch:  55   Loss:  181.11675326526165   Train Accuracy : 91.488
#
#
# Test accuracy: 88 %
# Epoch:  56   Loss:  181.66616585850716   Train Accuracy : 91.442
#
#
# Test accuracy: 88 %
# Epoch:  57   Loss:  180.5272949784994   Train Accuracy : 91.392
#
#
# Test accuracy: 88 %
# Epoch:  58   Loss:  176.48908932507038   Train Accuracy : 91.8
#
#
# Test accuracy: 88 %
# Epoch:  59   Loss:  172.44152382016182   Train Accuracy : 91.96
#
#
# Test accuracy: 88 %
# Epoch:  60   Loss:  153.94238090515137   Train Accuracy : 93.22
#
#
# Test accuracy: 89 %
# Epoch:  61   Loss:  150.22901964187622   Train Accuracy : 93.55
#
#
# Test accuracy: 89 %
# Epoch:  62   Loss:  146.12700225412846   Train Accuracy : 93.704
#
#
# Test accuracy: 89 %
# Epoch:  63   Loss:  144.33741736412048   Train Accuracy : 93.88
#
#
# Test accuracy: 89 %
# Epoch:  64   Loss:  142.46181546151638   Train Accuracy : 94.072
#
#
# Test accuracy: 89 %
# Epoch:  65   Loss:  136.32828606665134   Train Accuracy : 94.194
#
#
# Test accuracy: 89 %
# Epoch:  66   Loss:  138.35436072945595   Train Accuracy : 94.156
#
#
# Test accuracy: 89 %
# Epoch:  67   Loss:  134.69455687701702   Train Accuracy : 94.424
#
#
# Test accuracy: 89 %
# Epoch:  68   Loss:  130.63945500552654   Train Accuracy : 94.606
#
#
# Test accuracy: 89 %
# Epoch:  69   Loss:  132.3669242411852   Train Accuracy : 94.576
#
#
# Test accuracy: 89 %
# Epoch:  70   Loss:  131.30533768236637   Train Accuracy : 94.63
#
#
# Test accuracy: 89 %
# Epoch:  71   Loss:  133.0259194225073   Train Accuracy : 94.51
#
#
# Test accuracy: 89 %
# Epoch:  72   Loss:  130.32926627248526   Train Accuracy : 94.616
#
#
# Test accuracy: 89 %
# Epoch:  73   Loss:  127.91873541474342   Train Accuracy : 94.788
#
#
# Test accuracy: 89 %
# Epoch:  74   Loss:  127.22163426876068   Train Accuracy : 94.714
#
#
# Test accuracy: 90 %
# Epoch:  75   Loss:  129.29148840904236   Train Accuracy : 94.762
#
#
# Test accuracy: 89 %
# Epoch:  76   Loss:  127.85489296913147   Train Accuracy : 94.824
#
#
# Test accuracy: 89 %
# Epoch:  77   Loss:  126.09343414008617   Train Accuracy : 94.886
#
#
# Test accuracy: 89 %
# Epoch:  78   Loss:  124.30324278771877   Train Accuracy : 94.978
#
#
# Test accuracy: 89 %
# Epoch:  79   Loss:  120.1860636845231   Train Accuracy : 95.258
#
#
# Test accuracy: 89 %
# Epoch:  80   Loss:  110.76055826246738   Train Accuracy : 95.858
#
#
# Test accuracy: 90 %
# Epoch:  81   Loss:  104.5826613008976   Train Accuracy : 96.3
#
#
# Test accuracy: 90 %
# Epoch:  82   Loss:  101.2470802217722   Train Accuracy : 96.6
#
#
# Test accuracy: 90 %
# Epoch:  83   Loss:  99.79666744917631   Train Accuracy : 96.544
#
#
# Test accuracy: 90 %
# Epoch:  84   Loss:  99.87989763170481   Train Accuracy : 96.512
#
#
# Test accuracy: 90 %
# Epoch:  85   Loss:  96.08221918344498   Train Accuracy : 96.748
#
#
# Test accuracy: 90 %
# Epoch:  86   Loss:  97.138039752841   Train Accuracy : 96.814
#
#
# Test accuracy: 90 %
# Epoch:  87   Loss:  94.8983390852809   Train Accuracy : 96.842
#
#
# Test accuracy: 90 %
# Epoch:  88   Loss:  92.65219271183014   Train Accuracy : 96.974
#
#
# Test accuracy: 90 %
# Epoch:  89   Loss:  93.79905757308006   Train Accuracy : 96.914
#
#
# Test accuracy: 90 %
# Epoch:  90   Loss:  93.17624766379595   Train Accuracy : 96.922
#
#
# Test accuracy: 90 %
# Epoch:  91   Loss:  90.92930945754051   Train Accuracy : 96.974
#
#
# Test accuracy: 90 %
# Epoch:  92   Loss:  95.49932599812746   Train Accuracy : 96.788
#
#
# Test accuracy: 90 %
# Epoch:  93   Loss:  93.65386485308409   Train Accuracy : 96.926
#
#
# Test accuracy: 90 %
# Epoch:  94   Loss:  91.9748402312398   Train Accuracy : 96.982
#
#
# Test accuracy: 90 %
# Epoch:  95   Loss:  89.97816360741854   Train Accuracy : 97.106
#
#
# Test accuracy: 90 %
# Epoch:  96   Loss:  91.97855031490326   Train Accuracy : 96.958
#
#
# Test accuracy: 90 %
# Epoch:  97   Loss:  92.15315405279398   Train Accuracy : 96.91
#
#
# Test accuracy: 90 %
# Epoch:  98   Loss:  92.66061293333769   Train Accuracy : 96.894
#
#
# Test accuracy: 90 %
# Epoch:  99   Loss:  89.41366588324308   Train Accuracy : 97.05
#
#
# Test accuracy: 90 %
# Epoch:  100   Loss:  83.13761080056429   Train Accuracy : 97.524
#
#
# Test accuracy: 90 %
# Epoch:  101   Loss:  78.98184587806463   Train Accuracy : 97.802
#
#
# Test accuracy: 91 %
# Epoch:  102   Loss:  77.69441206753254   Train Accuracy : 97.922
#
#
# Test accuracy: 91 %
# Epoch:  103   Loss:  75.95165730267763   Train Accuracy : 97.986
#
#
# Test accuracy: 90 %
# Epoch:  104   Loss:  74.71015387773514   Train Accuracy : 98.044
#
#
# Test accuracy: 91 %
# Epoch:  105   Loss:  71.6302007958293   Train Accuracy : 98.136
#
#
# Test accuracy: 91 %
# Epoch:  106   Loss:  70.6877226009965   Train Accuracy : 98.214
#
#
# Test accuracy: 91 %
# Epoch:  107   Loss:  71.99403280764818   Train Accuracy : 98.188
#
#
# Test accuracy: 90 %
# Epoch:  108   Loss:  71.13652537763119   Train Accuracy : 98.19
#
#
# Test accuracy: 91 %
# Epoch:  109   Loss:  72.09674372524023   Train Accuracy : 98.216
#
#
# Test accuracy: 90 %
# Epoch:  110   Loss:  71.9537531286478   Train Accuracy : 98.128
#
#
# Test accuracy: 91 %
# Epoch:  111   Loss:  68.44317372143269   Train Accuracy : 98.384
#
#
# Test accuracy: 91 %
# Epoch:  112   Loss:  70.73579826205969   Train Accuracy : 98.268
#
#
# Test accuracy: 90 %
# Epoch:  113   Loss:  71.72850580513477   Train Accuracy : 98.104
#
#
# Test accuracy: 90 %
# Epoch:  114   Loss:  70.72880347818136   Train Accuracy : 98.24
#
#
# Test accuracy: 91 %
# Epoch:  115   Loss:  68.10197794437408   Train Accuracy : 98.394
#
#
# Test accuracy: 91 %
# Epoch:  116   Loss:  67.97728472203016   Train Accuracy : 98.366
#
#
# Test accuracy: 90 %
# Epoch:  117   Loss:  70.11850409209728   Train Accuracy : 98.244
#
#
# Test accuracy: 90 %
# Epoch:  118   Loss:  70.50261042267084   Train Accuracy : 98.256
#
#
# Test accuracy: 90 %
# Epoch:  119   Loss:  69.20828279107809   Train Accuracy : 98.378
#
#
# Test accuracy: 90 %
# Epoch:  120   Loss:  65.1315120011568   Train Accuracy : 98.578
#
#
# Test accuracy: 91 %
# Epoch:  121   Loss:  63.48753668367863   Train Accuracy : 98.724
#
#
# Test accuracy: 90 %
# Epoch:  122   Loss:  63.69061405956745   Train Accuracy : 98.66
#
#
# Test accuracy: 91 %
# Epoch:  123   Loss:  61.02791880071163   Train Accuracy : 98.9
#
#
# Test accuracy: 91 %
# Epoch:  124   Loss:  62.47184109315276   Train Accuracy : 98.74
#
#
# Test accuracy: 91 %
# Epoch:  125   Loss:  60.83759777620435   Train Accuracy : 98.816
#
#
# Test accuracy: 91 %
# Epoch:  126   Loss:  60.3047896400094   Train Accuracy : 98.822
#
#
# Test accuracy: 90 %
# Epoch:  127   Loss:  59.87093070149422   Train Accuracy : 98.872
#
#
# Test accuracy: 91 %
# Epoch:  128   Loss:  61.10842636227608   Train Accuracy : 98.804
#
#
# Test accuracy: 90 %
# Epoch:  129   Loss:  60.60153589770198   Train Accuracy : 98.794
#
#
# Test accuracy: 91 %
# Epoch:  130   Loss:  59.65140517055988   Train Accuracy : 98.858
#
#
# Test accuracy: 91 %
# Epoch:  131   Loss:  58.89955077692866   Train Accuracy : 98.872
#
#
# Test accuracy: 91 %
# Epoch:  132   Loss:  58.157433960586786   Train Accuracy : 98.97
#
#
# Test accuracy: 90 %
# Epoch:  133   Loss:  59.58282291889191   Train Accuracy : 98.8
#
#
# Test accuracy: 90 %
# Epoch:  134   Loss:  59.36661637946963   Train Accuracy : 98.872
#
#
# Test accuracy: 90 %
# Epoch:  135   Loss:  57.930059872567654   Train Accuracy : 98.978
#
#
# Test accuracy: 90 %
# Epoch:  136   Loss:  57.774424243718386   Train Accuracy : 98.93
#
#
# Test accuracy: 91 %
# Epoch:  137   Loss:  56.89045613631606   Train Accuracy : 99.052
#
#
# Test accuracy: 91 %
# Epoch:  138   Loss:  57.14453540742397   Train Accuracy : 98.978
#
#
# Test accuracy: 91 %
# Epoch:  139   Loss:  56.646180275827646   Train Accuracy : 98.99
#
#
# Test accuracy: 90 %
# Epoch:  140   Loss:  56.046450689435005   Train Accuracy : 99.072
#
#
# Test accuracy: 91 %
# Epoch:  141   Loss:  54.712650425732136   Train Accuracy : 99.164
#
#
# Test accuracy: 91 %
# Epoch:  142   Loss:  55.23339366912842   Train Accuracy : 99.07
#
#
# Test accuracy: 91 %
# Epoch:  143   Loss:  55.391948863863945   Train Accuracy : 99.05
#
#
# Test accuracy: 91 %
# Epoch:  144   Loss:  54.24056298285723   Train Accuracy : 99.06
#
#
# Test accuracy: 91 %
# Epoch:  145   Loss:  54.06393278390169   Train Accuracy : 99.166
#
#
# Test accuracy: 91 %
# Epoch:  146   Loss:  54.97297943010926   Train Accuracy : 99.148
#
#
# Test accuracy: 91 %
# Epoch:  147   Loss:  53.859437488019466   Train Accuracy : 99.134
#
#
# Test accuracy: 91 %
# Epoch:  148   Loss:  53.31878777220845   Train Accuracy : 99.18
#
#
# Test accuracy: 91 %
# Epoch:  149   Loss:  53.51835693791509   Train Accuracy : 99.19
#
#
# Test accuracy: 91 %
# Epoch:  150   Loss:  53.34698751568794   Train Accuracy : 99.176
#
#
# Test accuracy: 91 %
# Epoch:  151   Loss:  53.123432997614145   Train Accuracy : 99.144
#
#
# Test accuracy: 91 %
# Epoch:  152   Loss:  52.90338544920087   Train Accuracy : 99.228
#
#
# Test accuracy: 91 %

# %%
#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 91 %
# 91.3
# Accuracy of plane : 97 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 89 %
# Accuracy of   cat : 76 %
# Accuracy of  deer : 87 %
# Accuracy of   dog : 90 %
# Accuracy of  frog : 92 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 95 %
# Accuracy of truck : 100 %

# %%
'''  
The image lies between [0,1] but since I have trained the whole network on normalized input, Therefore
the min_val = -2.117 and max_val = 2.64 and not {0,1}
'''

# FGSM attack code
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, -2.117, 2.64)
    # Return the perturbed image
    return perturbed_image

def test( model, device, test_loader, epsilon ):

    # Accuracy counter
    correct = 0
    adv_examples = []

    # Loop over all examples in test set
    for data, target in test_loader:

        # Send the data and label to the device
        data, target = data.to(device), target.to(device)

        # Set requires_grad attribute of tensor. Important for Attack
        data.requires_grad = True

        # Forward pass the data through the model
        output = model(data)
        init_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability

        # If the initial prediction is wrong, dont bother attacking, just move on
        #if init_pred.item() != target.item():
        #    continue

        # Calculate the loss
        loss = F.nll_loss(output, target)

        # Zero all existing gradients
        model.zero_grad()

        # Calculate gradients of model in backward pass
        loss.backward()

        # Collect datagrad
        data_grad = data.grad.data

        # Call FGSM Attack
        perturbed_data = fgsm_attack(data, epsilon, data_grad)

        # Re-classify the perturbed image
        output = model(perturbed_data)

        # Check for success
        final_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        for i in range(0,len(final_pred)-1):
            if final_pred[i].sub(target[i]) == 0:
                correct += 1
                # Special case for saving 0 epsilon examples
                if (epsilon == 0) and (len(adv_examples) < 5):
                    adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                    adv_examples.append( (init_pred[i], final_pred[i], adv_ex) )
            else:
                # Save some adv examples for visualization later
                if len(adv_examples) < 5:
                    adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                    adv_examples.append( (init_pred[i], final_pred[i], adv_ex) )

    # Calculate final accuracy for this epsilon
    final_acc = correct/float(len(test_loader))
    print("Epsilon: {}\tTest Accuracy = {} / {} = {}".format(epsilon, correct, len(test_loader), final_acc))

    # Return the accuracy and an adversarial example
    return final_acc, adv_examples

# %%
#evaluate model
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = model(images.cuda())
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.cuda()).sum().item()

print('Accuracy on the test dataset is: %f %%' % (
    100 * correct / total))
# Out:
# Accuracy on the test dataset is: 91.300000 %

# %%
accuracies = []
examples = []
epsilons = [0, .05, .1, .15, .2, .25, .3]

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
use_cuda=True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

# Run test for each epsilon
for eps in epsilons:
    acc, ex = test(model, device, testloader, eps)
    accuracies.append(acc)
    examples.append(ex)
# Out:
# CUDA Available:  True
# Epsilon: 0	Test Accuracy = 9038 / 100 = 90.38
# Epsilon: 0.05	Test Accuracy = 5650 / 100 = 56.5
# Epsilon: 0.1	Test Accuracy = 5166 / 100 = 51.66
# Epsilon: 0.15	Test Accuracy = 4803 / 100 = 48.03
# Epsilon: 0.2	Test Accuracy = 4345 / 100 = 43.45
# Epsilon: 0.25	Test Accuracy = 3780 / 100 = 37.8
# Epsilon: 0.3	Test Accuracy = 3220 / 100 = 32.2

# %%
plt.figure(figsize=(5,5))
plt.plot(epsilons, torch.tensor(accuracies).div(100), "*-")
plt.yticks(np.arange(0, 1.1, step=0.1))
plt.xticks(np.arange(0, .35, step=0.05))
plt.title("Accuracy vs Epsilon")
plt.xlabel("Epsilon")
plt.ylabel("Accuracy")
plt.show()
